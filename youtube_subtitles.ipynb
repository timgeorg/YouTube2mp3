# %%
from youtube_transcript_api import YouTubeTranscriptApi
from datetime import timedelta

data = YouTubeTranscriptApi.get_transcript("cdiD-9MMpb0")

for item in data:
    item["end_time"] = item['start'] + item['duration']
    end_time = float(item['start']) + float(item['duration'])
    minutes, seconds = divmod(end_time, 60)
    item["minutes"] = minutes
    item["seconds"] = seconds
    item["timestamp"] = timedelta(minutes=item["minutes"], seconds=item["seconds"])

data
# Out:
# [{'text': "think it's possible that physics has",
#   'start': 0.0,
#   'duration': 3.06,
#   'end_time': 3.06,
#   'minutes': 0.0,
#   'seconds': 3.06,
#   'timestamp': datetime.timedelta(seconds=3, microseconds=60000)},
#  {'text': 'exploits and we should be trying to find',
#   'start': 1.62,
#   'duration': 3.24,
#   'end_time': 4.86,
#   'minutes': 0.0,
#   'seconds': 4.86,
#   'timestamp': datetime.timedelta(seconds=4, microseconds=860000)},
#  {'text': 'them arranging some kind of a crazy',
#   'start': 3.06,
#   'duration': 3.839,
#   'end_time': 6.899,
#   'minutes': 0.0,
#   'seconds': 6.899,
#   'timestamp': datetime.timedelta(seconds=6, microseconds=899000)},
#  {'text': 'quantum mechanical system that somehow',
#   'start': 4.86,
#   'duration': 4.199,
#   'end_time': 9.059000000000001,
#   'minutes': 0.0,
#   'seconds': 9.059000000000001,
#   'timestamp': datetime.timedelta(seconds=9, microseconds=59000)},
#  {'text': 'gives you buffer overflow somehow gives',
#   'start': 6.899,
#   'duration': 3.301,
#   'end_time': 10.2,
#   'minutes': 0.0,
#   'seconds': 10.2,
#   'timestamp': datetime.timedelta(seconds=10, microseconds=200000)},
#  {'text': 'you a rounding error in the floating',
#   'start': 9.059,
#   'duration': 4.08,
#   'end_time': 13.139,
#   'minutes': 0.0,
#   'seconds': 13.139,
#   'timestamp': datetime.timedelta(seconds=13, microseconds=139000)},
#  {'text': 'Point synthetic intelligences are kind',
#   'start': 10.2,
#   'duration': 4.58,
#   'end_time': 14.78,
#   'minutes': 0.0,
#   'seconds': 14.78,
#   'timestamp': datetime.timedelta(seconds=14, microseconds=780000)},
#  {'text': 'of like the next stage of development',
#   'start': 13.139,
#   'duration': 4.381,
#   'end_time': 17.52,
#   'minutes': 0.0,
#   'seconds': 17.52,
#   'timestamp': datetime.timedelta(seconds=17, microseconds=520000)},
#  {'text': "and I don't know where it leads to like",
#   'start': 14.78,
#   'duration': 5.2,
#   'end_time': 19.98,
#   'minutes': 0.0,
#   'seconds': 19.98,
#   'timestamp': datetime.timedelta(seconds=19, microseconds=980000)},
#  {'text': 'at some point I suspect',
#   'start': 17.52,
#   'duration': 5.12,
#   'end_time': 22.64,
#   'minutes': 0.0,
#   'seconds': 22.64,
#   'timestamp': datetime.timedelta(seconds=22, microseconds=640000)},
#  {'text': 'the universe is some kind of a puzzle',
#   'start': 19.98,
#   'duration': 5.219,
#   'end_time': 25.199,
#   'minutes': 0.0,
#   'seconds': 25.199,
#   'timestamp': datetime.timedelta(seconds=25, microseconds=199000)},
#  {'text': 'these synthetic AIS will uncover that',
#   'start': 22.64,
#   'duration': 4.18,
#   'end_time': 26.82,
#   'minutes': 0.0,
#   'seconds': 26.82,
#   'timestamp': datetime.timedelta(seconds=26, microseconds=820000)},
#  {'text': 'puzzle and',
#   'start': 25.199,
#   'duration': 4.521,
#   'end_time': 29.720000000000002,
#   'minutes': 0.0,
#   'seconds': 29.720000000000002,
#   'timestamp': datetime.timedelta(seconds=29, microseconds=720000)},
#  {'text': 'solve it',
#   'start': 26.82,
#   'duration': 2.9,
#   'end_time': 29.72,
#   'minutes': 0.0,
#   'seconds': 29.72,
#   'timestamp': datetime.timedelta(seconds=29, microseconds=720000)},
#  {'text': 'the following is a conversation with',
#   'start': 29.939,
#   'duration': 4.501,
#   'end_time': 34.44,
#   'minutes': 0.0,
#   'seconds': 34.44,
#   'timestamp': datetime.timedelta(seconds=34, microseconds=440000)},
#  {'text': 'Andre capothy previously the director of',
#   'start': 31.679,
#   'duration': 6.241,
#   'end_time': 37.92,
#   'minutes': 0.0,
#   'seconds': 37.92,
#   'timestamp': datetime.timedelta(seconds=37, microseconds=920000)},
#  {'text': 'AI at Tesla and before that at open Ai',
#   'start': 34.44,
#   'duration': 7.279,
#   'end_time': 41.718999999999994,
#   'minutes': 0.0,
#   'seconds': 41.718999999999994,
#   'timestamp': datetime.timedelta(seconds=41, microseconds=719000)},
#  {'text': 'and Stanford he is one of the greatest',
#   'start': 37.92,
#   'duration': 7.319,
#   'end_time': 45.239000000000004,
#   'minutes': 0.0,
#   'seconds': 45.239000000000004,
#   'timestamp': datetime.timedelta(seconds=45, microseconds=239000)},
#  {'text': 'scientists engineers and Educators in',
#   'start': 41.719,
#   'duration': 5.921,
#   'end_time': 47.64,
#   'minutes': 0.0,
#   'seconds': 47.64,
#   'timestamp': datetime.timedelta(seconds=47, microseconds=640000)},
#  {'text': 'the history of artificial intelligence',
#   'start': 45.239,
#   'duration': 5.221,
#   'end_time': 50.459999999999994,
#   'minutes': 0.0,
#   'seconds': 50.459999999999994,
#   'timestamp': datetime.timedelta(seconds=50, microseconds=460000)},
#  {'text': 'this is the Lex Friedman podcast to',
#   'start': 47.64,
#   'duration': 4.739,
#   'end_time': 52.379,
#   'minutes': 0.0,
#   'seconds': 52.379,
#   'timestamp': datetime.timedelta(seconds=52, microseconds=379000)},
#  {'text': 'support it please check out our sponsors',
#   'start': 50.46,
#   'duration': 5.34,
#   'end_time': 55.8,
#   'minutes': 0.0,
#   'seconds': 55.8,
#   'timestamp': datetime.timedelta(seconds=55, microseconds=800000)},
#  {'text': "and now dear friends here's Andre",
#   'start': 52.379,
#   'duration': 5.581,
#   'end_time': 57.96,
#   'minutes': 0.0,
#   'seconds': 57.96,
#   'timestamp': datetime.timedelta(seconds=57, microseconds=960000)},
#  {'text': 'capathi',
#   'start': 55.8,
#   'duration': 5.16,
#   'end_time': 60.959999999999994,
#   'minutes': 1.0,
#   'seconds': 0.9599999999999937,
#   'timestamp': datetime.timedelta(seconds=60, microseconds=960000)},
#  {'text': 'what is a neural network and why does it',
#   'start': 57.96,
#   'duration': 5.399,
#   'end_time': 63.359,
#   'minutes': 1.0,
#   'seconds': 3.3590000000000018,
#   'timestamp': datetime.timedelta(seconds=63, microseconds=359000)},
#  {'text': 'seem to uh do such a surprisingly good',
#   'start': 60.96,
#   'duration': 4.379,
#   'end_time': 65.339,
#   'minutes': 1.0,
#   'seconds': 5.338999999999999,
#   'timestamp': datetime.timedelta(seconds=65, microseconds=339000)},
#  {'text': 'job of learning what is a neural network',
#   'start': 63.359,
#   'duration': 5.521,
#   'end_time': 68.88,
#   'minutes': 1.0,
#   'seconds': 8.879999999999995,
#   'timestamp': datetime.timedelta(seconds=68, microseconds=880000)},
#  {'text': "it's a mathematical abstraction of",
#   'start': 65.339,
#   'duration': 5.701,
#   'end_time': 71.03999999999999,
#   'minutes': 1.0,
#   'seconds': 11.039999999999992,
#   'timestamp': datetime.timedelta(seconds=71, microseconds=40000)},
#  {'text': "the brain I would say that's how it was",
#   'start': 68.88,
#   'duration': 3.66,
#   'end_time': 72.53999999999999,
#   'minutes': 1.0,
#   'seconds': 12.539999999999992,
#   'timestamp': datetime.timedelta(seconds=72, microseconds=540000)},
#  {'text': 'originally developed',
#   'start': 71.04,
#   'duration': 2.579,
#   'end_time': 73.619,
#   'minutes': 1.0,
#   'seconds': 13.619,
#   'timestamp': datetime.timedelta(seconds=73, microseconds=619000)},
#  {'text': "at the end of the day it's a",
#   'start': 72.54,
#   'duration': 2.46,
#   'end_time': 75.0,
#   'minutes': 1.0,
#   'seconds': 15.0,
#   'timestamp': datetime.timedelta(seconds=75)},
#  {'text': "mathematical expression and it's a",
#   'start': 73.619,
#   'duration': 2.521,
#   'end_time': 76.14,
#   'minutes': 1.0,
#   'seconds': 16.14,
#   'timestamp': datetime.timedelta(seconds=76, microseconds=140000)},
#  {'text': 'fairly simple mathematical expression',
#   'start': 75.0,
#   'duration': 3.96,
#   'end_time': 78.96,
#   'minutes': 1.0,
#   'seconds': 18.959999999999994,
#   'timestamp': datetime.timedelta(seconds=78, microseconds=960000)},
#  {'text': "when you get down to it it's basically a",
#   'start': 76.14,
#   'duration': 5.519,
#   'end_time': 81.659,
#   'minutes': 1.0,
#   'seconds': 21.659000000000006,
#   'timestamp': datetime.timedelta(seconds=81, microseconds=659000)},
#  {'text': 'sequence of Matrix multiplies which are',
#   'start': 78.96,
#   'duration': 4.92,
#   'end_time': 83.88,
#   'minutes': 1.0,
#   'seconds': 23.879999999999995,
#   'timestamp': datetime.timedelta(seconds=83, microseconds=880000)},
#  {'text': 'really dot products mathematically and',
#   'start': 81.659,
#   'duration': 4.14,
#   'end_time': 85.799,
#   'minutes': 1.0,
#   'seconds': 25.799000000000007,
#   'timestamp': datetime.timedelta(seconds=85, microseconds=799000)},
#  {'text': 'some nonlinearities thrown in and so',
#   'start': 83.88,
#   'duration': 2.94,
#   'end_time': 86.82,
#   'minutes': 1.0,
#   'seconds': 26.819999999999993,
#   'timestamp': datetime.timedelta(seconds=86, microseconds=820000)},
#  {'text': "it's a very simple mathematical",
#   'start': 85.799,
#   'duration': 3.781,
#   'end_time': 89.58000000000001,
#   'minutes': 1.0,
#   'seconds': 29.580000000000013,
#   'timestamp': datetime.timedelta(seconds=89, microseconds=580000)},
#  {'text': "expression and it's got knobs in it many",
#   'start': 86.82,
#   'duration': 4.979,
#   'end_time': 91.79899999999999,
#   'minutes': 1.0,
#   'seconds': 31.798999999999992,
#   'timestamp': datetime.timedelta(seconds=91, microseconds=799000)},
#  {'text': 'knobs many knobs and these knobs are',
#   'start': 89.58,
#   'duration': 3.78,
#   'end_time': 93.36,
#   'minutes': 1.0,
#   'seconds': 33.36,
#   'timestamp': datetime.timedelta(seconds=93, microseconds=360000)},
#  {'text': 'Loosely related to basically the',
#   'start': 91.799,
#   'duration': 3.0,
#   'end_time': 94.799,
#   'minutes': 1.0,
#   'seconds': 34.79900000000001,
#   'timestamp': datetime.timedelta(seconds=94, microseconds=799000)},
#  {'text': "synapses in your brain they're trainable",
#   'start': 93.36,
#   'duration': 3.299,
#   'end_time': 96.659,
#   'minutes': 1.0,
#   'seconds': 36.659000000000006,
#   'timestamp': datetime.timedelta(seconds=96, microseconds=659000)},
#  {'text': "they're modifiable and so the idea is",
#   'start': 94.799,
#   'duration': 3.301,
#   'end_time': 98.10000000000001,
#   'minutes': 1.0,
#   'seconds': 38.10000000000001,
#   'timestamp': datetime.timedelta(seconds=98, microseconds=100000)},
#  {'text': 'like we need to find the setting of The',
#   'start': 96.659,
#   'duration': 3.96,
#   'end_time': 100.619,
#   'minutes': 1.0,
#   'seconds': 40.619,
#   'timestamp': datetime.timedelta(seconds=100, microseconds=619000)},
#  {'text': 'Knobs that makes the neural nut do',
#   'start': 98.1,
#   'duration': 4.08,
#   'end_time': 102.17999999999999,
#   'minutes': 1.0,
#   'seconds': 42.17999999999999,
#   'timestamp': datetime.timedelta(seconds=102, microseconds=180000)},
#  {'text': 'whatever you want it to do like classify',
#   'start': 100.619,
#   'duration': 4.14,
#   'end_time': 104.759,
#   'minutes': 1.0,
#   'seconds': 44.759,
#   'timestamp': datetime.timedelta(seconds=104, microseconds=759000)},
#  {'text': "images and so on and so there's not too",
#   'start': 102.18,
#   'duration': 4.74,
#   'end_time': 106.92,
#   'minutes': 1.0,
#   'seconds': 46.92,
#   'timestamp': datetime.timedelta(seconds=106, microseconds=920000)},
#  {'text': 'much mystery I would say in it like',
#   'start': 104.759,
#   'duration': 4.381,
#   'end_time': 109.14,
#   'minutes': 1.0,
#   'seconds': 49.14,
#   'timestamp': datetime.timedelta(seconds=109, microseconds=140000)},
#  {'text': "um you might think that basically don't",
#   'start': 106.92,
#   'duration': 3.36,
#   'end_time': 110.28,
#   'minutes': 1.0,
#   'seconds': 50.28,
#   'timestamp': datetime.timedelta(seconds=110, microseconds=280000)},
#  {'text': 'want to endow it with too much meaning',
#   'start': 109.14,
#   'duration': 3.18,
#   'end_time': 112.32000000000001,
#   'minutes': 1.0,
#   'seconds': 52.32000000000001,
#   'timestamp': datetime.timedelta(seconds=112, microseconds=320000)},
#  {'text': 'with respect to the brain and how it',
#   'start': 110.28,
#   'duration': 3.839,
#   'end_time': 114.119,
#   'minutes': 1.0,
#   'seconds': 54.119,
#   'timestamp': datetime.timedelta(seconds=114, microseconds=119000)},
#  {'text': "works it's really just a complicated",
#   'start': 112.32,
#   'duration': 3.42,
#   'end_time': 115.74,
#   'minutes': 1.0,
#   'seconds': 55.739999999999995,
#   'timestamp': datetime.timedelta(seconds=115, microseconds=740000)},
#  {'text': 'mathematical expression with knobs and',
#   'start': 114.119,
#   'duration': 3.721,
#   'end_time': 117.84,
#   'minutes': 1.0,
#   'seconds': 57.84,
#   'timestamp': datetime.timedelta(seconds=117, microseconds=840000)},
#  {'text': 'those knobs need a proper setting for it',
#   'start': 115.74,
#   'duration': 4.019,
#   'end_time': 119.759,
#   'minutes': 1.0,
#   'seconds': 59.759,
#   'timestamp': datetime.timedelta(seconds=119, microseconds=759000)},
#  {'text': 'to do something uh desirable yeah but',
#   'start': 117.84,
#   'duration': 4.319,
#   'end_time': 122.159,
#   'minutes': 2.0,
#   'seconds': 2.159000000000006,
#   'timestamp': datetime.timedelta(seconds=122, microseconds=159000)},
#  {'text': 'poetry is just the collection of letters',
#   'start': 119.759,
#   'duration': 4.921,
#   'end_time': 124.68,
#   'minutes': 2.0,
#   'seconds': 4.680000000000007,
#   'timestamp': datetime.timedelta(seconds=124, microseconds=680000)},
#  {'text': 'with spaces but it can make us feel a',
#   'start': 122.159,
#   'duration': 4.261,
#   'end_time': 126.42,
#   'minutes': 2.0,
#   'seconds': 6.420000000000002,
#   'timestamp': datetime.timedelta(seconds=126, microseconds=420000)},
#  {'text': 'certain way and in that same way when',
#   'start': 124.68,
#   'duration': 3.48,
#   'end_time': 128.16,
#   'minutes': 2.0,
#   'seconds': 8.159999999999997,
#   'timestamp': datetime.timedelta(seconds=128, microseconds=160000)},
#  {'text': 'you get a large number of knobs together',
#   'start': 126.42,
#   'duration': 4.74,
#   'end_time': 131.16,
#   'minutes': 2.0,
#   'seconds': 11.159999999999997,
#   'timestamp': datetime.timedelta(seconds=131, microseconds=160000)},
#  {'text': "whether it's in a inside the brain or",
#   'start': 128.16,
#   'duration': 5.76,
#   'end_time': 133.92,
#   'minutes': 2.0,
#   'seconds': 13.919999999999987,
#   'timestamp': datetime.timedelta(seconds=133, microseconds=920000)},
#  {'text': 'inside a computer they seem to they seem',
#   'start': 131.16,
#   'duration': 4.68,
#   'end_time': 135.84,
#   'minutes': 2.0,
#   'seconds': 15.840000000000003,
#   'timestamp': datetime.timedelta(seconds=135, microseconds=840000)},
#  {'text': 'to surprise us with the with their power',
#   'start': 133.92,
#   'duration': 4.14,
#   'end_time': 138.05999999999997,
#   'minutes': 2.0,
#   'seconds': 18.059999999999974,
#   'timestamp': datetime.timedelta(seconds=138, microseconds=60000)},
#  {'text': "yeah I think that's fair so basically",
#   'start': 135.84,
#   'duration': 5.16,
#   'end_time': 141.0,
#   'minutes': 2.0,
#   'seconds': 21.0,
#   'timestamp': datetime.timedelta(seconds=141)},
#  {'text': "I'm underselling it by a lot because you",
#   'start': 138.06,
#   'duration': 4.98,
#   'end_time': 143.04,
#   'minutes': 2.0,
#   'seconds': 23.039999999999992,
#   'timestamp': datetime.timedelta(seconds=143, microseconds=40000)},
#  {'text': 'definitely do get very surprising',
#   'start': 141.0,
#   'duration': 4.14,
#   'end_time': 145.14,
#   'minutes': 2.0,
#   'seconds': 25.139999999999986,
#   'timestamp': datetime.timedelta(seconds=145, microseconds=140000)},
#  {'text': 'emergent behaviors out of these neurons',
#   'start': 143.04,
#   'duration': 3.839,
#   'end_time': 146.879,
#   'minutes': 2.0,
#   'seconds': 26.87899999999999,
#   'timestamp': datetime.timedelta(seconds=146, microseconds=879000)},
#  {'text': "when they're large enough and trained on",
#   'start': 145.14,
#   'duration': 4.26,
#   'end_time': 149.39999999999998,
#   'minutes': 2.0,
#   'seconds': 29.399999999999977,
#   'timestamp': datetime.timedelta(seconds=149, microseconds=400000)},
#  {'text': 'complicated enough problems like say for',
#   'start': 146.879,
#   'duration': 4.86,
#   'end_time': 151.739,
#   'minutes': 2.0,
#   'seconds': 31.739000000000004,
#   'timestamp': datetime.timedelta(seconds=151, microseconds=739000)},
#  {'text': 'example the next uh word prediction in a',
#   'start': 149.4,
#   'duration': 4.62,
#   'end_time': 154.02,
#   'minutes': 2.0,
#   'seconds': 34.02000000000001,
#   'timestamp': datetime.timedelta(seconds=154, microseconds=20000)},
#  {'text': 'massive data set from the internet and',
#   'start': 151.739,
#   'duration': 4.14,
#   'end_time': 155.879,
#   'minutes': 2.0,
#   'seconds': 35.87899999999999,
#   'timestamp': datetime.timedelta(seconds=155, microseconds=879000)},
#  {'text': 'then these neurons take on a pretty',
#   'start': 154.02,
#   'duration': 4.14,
#   'end_time': 158.16,
#   'minutes': 2.0,
#   'seconds': 38.16,
#   'timestamp': datetime.timedelta(seconds=158, microseconds=160000)},
#  {'text': 'surprising magical properties yeah I',
#   'start': 155.879,
#   'duration': 3.481,
#   'end_time': 159.35999999999999,
#   'minutes': 2.0,
#   'seconds': 39.359999999999985,
#   'timestamp': datetime.timedelta(seconds=159, microseconds=360000)},
#  {'text': "think it's kind of interesting how much",
#   'start': 158.16,
#   'duration': 2.939,
#   'end_time': 161.099,
#   'minutes': 2.0,
#   'seconds': 41.09899999999999,
#   'timestamp': datetime.timedelta(seconds=161, microseconds=99000)},
#  {'text': 'you can get out of even very simple',
#   'start': 159.36,
#   'duration': 3.72,
#   'end_time': 163.08,
#   'minutes': 2.0,
#   'seconds': 43.08000000000001,
#   'timestamp': datetime.timedelta(seconds=163, microseconds=80000)},
#  {'text': 'mathematical formalism when your brain',
#   'start': 161.099,
#   'duration': 4.201,
#   'end_time': 165.29999999999998,
#   'minutes': 2.0,
#   'seconds': 45.29999999999998,
#   'timestamp': datetime.timedelta(seconds=165, microseconds=300000)},
#  {'text': 'right now I was talking is it doing next',
#   'start': 163.08,
#   'duration': 4.019,
#   'end_time': 167.09900000000002,
#   'minutes': 2.0,
#   'seconds': 47.09900000000002,
#   'timestamp': datetime.timedelta(seconds=167, microseconds=99000)},
#  {'text': 'word prediction',
#   'start': 165.3,
#   'duration': 3.12,
#   'end_time': 168.42000000000002,
#   'minutes': 2.0,
#   'seconds': 48.420000000000016,
#   'timestamp': datetime.timedelta(seconds=168, microseconds=420000)},
#  {'text': 'or is it doing something more',
#   'start': 167.099,
#   'duration': 3.121,
#   'end_time': 170.22,
#   'minutes': 2.0,
#   'seconds': 50.22,
#   'timestamp': datetime.timedelta(seconds=170, microseconds=220000)},
#  {'text': 'interesting well definitely some kind of',
#   'start': 168.42,
#   'duration': 4.14,
#   'end_time': 172.55999999999997,
#   'minutes': 2.0,
#   'seconds': 52.559999999999974,
#   'timestamp': datetime.timedelta(seconds=172, microseconds=560000)},
#  {'text': "a generative model that's a gpt-like and",
#   'start': 170.22,
#   'duration': 4.14,
#   'end_time': 174.35999999999999,
#   'minutes': 2.0,
#   'seconds': 54.359999999999985,
#   'timestamp': datetime.timedelta(seconds=174, microseconds=360000)},
#  {'text': 'prompted by you',
#   'start': 172.56,
#   'duration': 3.42,
#   'end_time': 175.98,
#   'minutes': 2.0,
#   'seconds': 55.97999999999999,
#   'timestamp': datetime.timedelta(seconds=175, microseconds=980000)},
#  {'text': "um yeah so you're giving me a prompt and",
#   'start': 174.36,
#   'duration': 3.599,
#   'end_time': 177.959,
#   'minutes': 2.0,
#   'seconds': 57.959,
#   'timestamp': datetime.timedelta(seconds=177, microseconds=959000)},
#  {'text': "I'm kind of like responding to it in a",
#   'start': 175.98,
#   'duration': 4.56,
#   'end_time': 180.54,
#   'minutes': 3.0,
#   'seconds': 0.539999999999992,
#   'timestamp': datetime.timedelta(seconds=180, microseconds=540000)},
#  {'text': 'generative way and by yourself perhaps a',
#   'start': 177.959,
#   'duration': 5.161,
#   'end_time': 183.12,
#   'minutes': 3.0,
#   'seconds': 3.1200000000000045,
#   'timestamp': datetime.timedelta(seconds=183, microseconds=120000)},
#  {'text': 'little bit like are you adding extra',
#   'start': 180.54,
#   'duration': 4.86,
#   'end_time': 185.4,
#   'minutes': 3.0,
#   'seconds': 5.400000000000006,
#   'timestamp': datetime.timedelta(seconds=185, microseconds=400000)},
#  {'text': 'prompts from your own memory inside your',
#   'start': 183.12,
#   'duration': 3.259,
#   'end_time': 186.379,
#   'minutes': 3.0,
#   'seconds': 6.378999999999991,
#   'timestamp': datetime.timedelta(seconds=186, microseconds=379000)},
#  {'text': 'head',
#   'start': 185.4,
#   'duration': 2.52,
#   'end_time': 187.92000000000002,
#   'minutes': 3.0,
#   'seconds': 7.920000000000016,
#   'timestamp': datetime.timedelta(seconds=187, microseconds=920000)},
#  {'text': "automatically feels like you're",
#   'start': 186.379,
#   'duration': 3.161,
#   'end_time': 189.54,
#   'minutes': 3.0,
#   'seconds': 9.539999999999992,
#   'timestamp': datetime.timedelta(seconds=189, microseconds=540000)},
#  {'text': 'referencing some kind of a declarative',
#   'start': 187.92,
#   'duration': 4.8,
#   'end_time': 192.72,
#   'minutes': 3.0,
#   'seconds': 12.719999999999999,
#   'timestamp': datetime.timedelta(seconds=192, microseconds=720000)},
#  {'text': 'structure of like memory and so on and',
#   'start': 189.54,
#   'duration': 5.1,
#   'end_time': 194.64,
#   'minutes': 3.0,
#   'seconds': 14.639999999999986,
#   'timestamp': datetime.timedelta(seconds=194, microseconds=640000)},
#  {'text': "then uh you're putting that together",
#   'start': 192.72,
#   'duration': 4.14,
#   'end_time': 196.85999999999999,
#   'minutes': 3.0,
#   'seconds': 16.859999999999985,
#   'timestamp': datetime.timedelta(seconds=196, microseconds=860000)},
#  {'text': 'with your prompt and giving away some',
#   'start': 194.64,
#   'duration': 4.14,
#   'end_time': 198.77999999999997,
#   'minutes': 3.0,
#   'seconds': 18.779999999999973,
#   'timestamp': datetime.timedelta(seconds=198, microseconds=780000)},
#  {'text': 'messages like how much of what you just',
#   'start': 196.86,
#   'duration': 4.86,
#   'end_time': 201.72000000000003,
#   'minutes': 3.0,
#   'seconds': 21.720000000000027,
#   'timestamp': datetime.timedelta(seconds=201, microseconds=720000)},
#  {'text': 'said has been said by you before',
#   'start': 198.78,
#   'duration': 6.36,
#   'end_time': 205.14000000000001,
#   'minutes': 3.0,
#   'seconds': 25.140000000000015,
#   'timestamp': datetime.timedelta(seconds=205, microseconds=140000)},
#  {'text': 'uh nothing basically right no but if you',
#   'start': 201.72,
#   'duration': 4.62,
#   'end_time': 206.34,
#   'minutes': 3.0,
#   'seconds': 26.340000000000003,
#   'timestamp': datetime.timedelta(seconds=206, microseconds=340000)},
#  {'text': "actually look at all the words you've",
#   'start': 205.14,
#   'duration': 3.3,
#   'end_time': 208.44,
#   'minutes': 3.0,
#   'seconds': 28.439999999999998,
#   'timestamp': datetime.timedelta(seconds=208, microseconds=440000)},
#  {'text': 'ever said in your life and you do a',
#   'start': 206.34,
#   'duration': 5.16,
#   'end_time': 211.5,
#   'minutes': 3.0,
#   'seconds': 31.5,
#   'timestamp': datetime.timedelta(seconds=211, microseconds=500000)},
#  {'text': "search you'll probably said a lot of the",
#   'start': 208.44,
#   'duration': 6.0,
#   'end_time': 214.44,
#   'minutes': 3.0,
#   'seconds': 34.44,
#   'timestamp': datetime.timedelta(seconds=214, microseconds=440000)},
#  {'text': 'same words in the same order before yeah',
#   'start': 211.5,
#   'duration': 4.98,
#   'end_time': 216.48,
#   'minutes': 3.0,
#   'seconds': 36.47999999999999,
#   'timestamp': datetime.timedelta(seconds=216, microseconds=480000)},
#  {'text': "it could be I mean I'm using phrases",
#   'start': 214.44,
#   'duration': 4.079,
#   'end_time': 218.519,
#   'minutes': 3.0,
#   'seconds': 38.519000000000005,
#   'timestamp': datetime.timedelta(seconds=218, microseconds=519000)},
#  {'text': "that are common Etc but I'm remixing it",
#   'start': 216.48,
#   'duration': 4.92,
#   'end_time': 221.39999999999998,
#   'minutes': 3.0,
#   'seconds': 41.39999999999998,
#   'timestamp': datetime.timedelta(seconds=221, microseconds=400000)},
#  {'text': 'into a pretty uh sort of unique sentence',
#   'start': 218.519,
#   'duration': 4.021,
#   'end_time': 222.54,
#   'minutes': 3.0,
#   'seconds': 42.53999999999999,
#   'timestamp': datetime.timedelta(seconds=222, microseconds=540000)},
#  {'text': "at the end of the day but you're right",
#   'start': 221.4,
#   'duration': 2.28,
#   'end_time': 223.68,
#   'minutes': 3.0,
#   'seconds': 43.68000000000001,
#   'timestamp': datetime.timedelta(seconds=223, microseconds=680000)},
#  {'text': "definitely there's like a ton of",
#   'start': 222.54,
#   'duration': 4.259,
#   'end_time': 226.79899999999998,
#   'minutes': 3.0,
#   'seconds': 46.79899999999998,
#   'timestamp': datetime.timedelta(seconds=226, microseconds=799000)},
#  {'text': "remixing what you didn't you it's like",
#   'start': 223.68,
#   'duration': 5.9,
#   'end_time': 229.58,
#   'minutes': 3.0,
#   'seconds': 49.58000000000001,
#   'timestamp': datetime.timedelta(seconds=229, microseconds=580000)},
#  {'text': "Magnus Carlsen said uh I'm I'm rated",
#   'start': 226.799,
#   'duration': 5.881,
#   'end_time': 232.68,
#   'minutes': 3.0,
#   'seconds': 52.68000000000001,
#   'timestamp': datetime.timedelta(seconds=232, microseconds=680000)},
#  {'text': '2900 whatever which is pretty decent I',
#   'start': 229.58,
#   'duration': 6.159,
#   'end_time': 235.739,
#   'minutes': 3.0,
#   'seconds': 55.739000000000004,
#   'timestamp': datetime.timedelta(seconds=235, microseconds=739000)},
#  {'text': "think you're talking very uh you're not",
#   'start': 232.68,
#   'duration': 4.88,
#   'end_time': 237.56,
#   'minutes': 3.0,
#   'seconds': 57.56,
#   'timestamp': datetime.timedelta(seconds=237, microseconds=560000)},
#  {'text': 'giving enough credit to neural Nets here',
#   'start': 235.739,
#   'duration': 4.92,
#   'end_time': 240.659,
#   'minutes': 4.0,
#   'seconds': 0.6589999999999918,
#   'timestamp': datetime.timedelta(seconds=240, microseconds=659000)},
#  {'text': 'why do they seem to',
#   'start': 237.56,
#   'duration': 5.5,
#   'end_time': 243.06,
#   'minutes': 4.0,
#   'seconds': 3.0600000000000023,
#   'timestamp': datetime.timedelta(seconds=243, microseconds=60000)},
#  {'text': "what's your best intuition",
#   'start': 240.659,
#   'duration': 5.341,
#   'end_time': 246.0,
#   'minutes': 4.0,
#   'seconds': 6.0,
#   'timestamp': datetime.timedelta(seconds=246)},
#  {'text': "about this emergent Behavior I mean it's",
#   'start': 243.06,
#   'duration': 3.84,
#   'end_time': 246.9,
#   'minutes': 4.0,
#   'seconds': 6.900000000000006,
#   'timestamp': datetime.timedelta(seconds=246, microseconds=900000)},
#  {'text': "kind of interesting because I'm",
#   'start': 246.0,
#   'duration': 3.299,
#   'end_time': 249.299,
#   'minutes': 4.0,
#   'seconds': 9.299000000000007,
#   'timestamp': datetime.timedelta(seconds=249, microseconds=299000)},
#  {'text': 'simultaneously underselling them but I',
#   'start': 246.9,
#   'duration': 3.419,
#   'end_time': 250.31900000000002,
#   'minutes': 4.0,
#   'seconds': 10.319000000000017,
#   'timestamp': datetime.timedelta(seconds=250, microseconds=319000)},
#  {'text': "also feel like there's an element to",
#   'start': 249.299,
#   'duration': 3.0,
#   'end_time': 252.299,
#   'minutes': 4.0,
#   'seconds': 12.299000000000007,
#   'timestamp': datetime.timedelta(seconds=252, microseconds=299000)},
#  {'text': "which I'm over like it's actually kind",
#   'start': 250.319,
#   'duration': 3.42,
#   'end_time': 253.73899999999998,
#   'minutes': 4.0,
#   'seconds': 13.738999999999976,
#   'timestamp': datetime.timedelta(seconds=253, microseconds=739000)},
#  {'text': 'of incredible that you can get so much',
#   'start': 252.299,
#   'duration': 2.881,
#   'end_time': 255.18,
#   'minutes': 4.0,
#   'seconds': 15.180000000000007,
#   'timestamp': datetime.timedelta(seconds=255, microseconds=180000)},
#  {'text': 'emergent magical Behavior out of them',
#   'start': 253.739,
#   'duration': 2.701,
#   'end_time': 256.44,
#   'minutes': 4.0,
#   'seconds': 16.439999999999998,
#   'timestamp': datetime.timedelta(seconds=256, microseconds=440000)},
#  {'text': 'despite them being so simple',
#   'start': 255.18,
#   'duration': 3.239,
#   'end_time': 258.419,
#   'minutes': 4.0,
#   'seconds': 18.418999999999983,
#   'timestamp': datetime.timedelta(seconds=258, microseconds=419000)},
#  {'text': 'mathematically so I think those are kind',
#   'start': 256.44,
#   'duration': 3.66,
#   'end_time': 260.1,
#   'minutes': 4.0,
#   'seconds': 20.100000000000023,
#   'timestamp': datetime.timedelta(seconds=260, microseconds=100000)},
#  {'text': 'of like two surprising statements that',
#   'start': 258.419,
#   'duration': 4.141,
#   'end_time': 262.56,
#   'minutes': 4.0,
#   'seconds': 22.560000000000002,
#   'timestamp': datetime.timedelta(seconds=262, microseconds=560000)},
#  {'text': 'are kind of just juxtapose together',
#   'start': 260.1,
#   'duration': 4.26,
#   'end_time': 264.36,
#   'minutes': 4.0,
#   'seconds': 24.360000000000014,
#   'timestamp': datetime.timedelta(seconds=264, microseconds=360000)},
#  {'text': 'and I think basically what it is is we',
#   'start': 262.56,
#   'duration': 3.359,
#   'end_time': 265.919,
#   'minutes': 4.0,
#   'seconds': 25.918999999999983,
#   'timestamp': datetime.timedelta(seconds=265, microseconds=919000)},
#  {'text': 'are actually fairly good at optimizing',
#   'start': 264.36,
#   'duration': 3.779,
#   'end_time': 268.139,
#   'minutes': 4.0,
#   'seconds': 28.13900000000001,
#   'timestamp': datetime.timedelta(seconds=268, microseconds=139000)},
#  {'text': 'these neural Nets and when you give them',
#   'start': 265.919,
#   'duration': 4.861,
#   'end_time': 270.78,
#   'minutes': 4.0,
#   'seconds': 30.779999999999973,
#   'timestamp': datetime.timedelta(seconds=270, microseconds=780000)},
#  {'text': 'a hard enough problem they are forced to',
#   'start': 268.139,
#   'duration': 4.981,
#   'end_time': 273.12,
#   'minutes': 4.0,
#   'seconds': 33.120000000000005,
#   'timestamp': datetime.timedelta(seconds=273, microseconds=120000)},
#  {'text': 'learn very interesting Solutions in the',
#   'start': 270.78,
#   'duration': 4.44,
#   'end_time': 275.21999999999997,
#   'minutes': 4.0,
#   'seconds': 35.21999999999997,
#   'timestamp': datetime.timedelta(seconds=275, microseconds=220000)},
#  {'text': 'optimization and those solution',
#   'start': 273.12,
#   'duration': 4.079,
#   'end_time': 277.199,
#   'minutes': 4.0,
#   'seconds': 37.19900000000001,
#   'timestamp': datetime.timedelta(seconds=277, microseconds=199000)},
#  {'text': 'basically have these immersion',
#   'start': 275.22,
#   'duration': 3.12,
#   'end_time': 278.34000000000003,
#   'minutes': 4.0,
#   'seconds': 38.34000000000003,
#   'timestamp': datetime.timedelta(seconds=278, microseconds=340000)},
#  {'text': 'properties that are very interesting',
#   'start': 277.199,
#   'duration': 3.901,
#   'end_time': 281.1,
#   'minutes': 4.0,
#   'seconds': 41.10000000000002,
#   'timestamp': datetime.timedelta(seconds=281, microseconds=100000)},
#  {'text': "there's wisdom and knowledge",
#   'start': 278.34,
#   'duration': 4.94,
#   'end_time': 283.28,
#   'minutes': 4.0,
#   'seconds': 43.27999999999997,
#   'timestamp': datetime.timedelta(seconds=283, microseconds=280000)},
#  {'text': 'in the knobs',
#   'start': 281.1,
#   'duration': 5.099,
#   'end_time': 286.199,
#   'minutes': 4.0,
#   'seconds': 46.19900000000001,
#   'timestamp': datetime.timedelta(seconds=286, microseconds=199000)},
#  {'text': "and so what's this representation that's",
#   'start': 283.28,
#   'duration': 5.68,
#   'end_time': 288.96,
#   'minutes': 4.0,
#   'seconds': 48.95999999999998,
#   'timestamp': datetime.timedelta(seconds=288, microseconds=960000)},
#  {'text': 'in the knobs does it make sense to you',
#   'start': 286.199,
#   'duration': 4.801,
#   'end_time': 291.0,
#   'minutes': 4.0,
#   'seconds': 51.0,
#   'timestamp': datetime.timedelta(seconds=291)},
#  {'text': 'intuitively the large number of knobs',
#   'start': 288.96,
#   'duration': 4.08,
#   'end_time': 293.03999999999996,
#   'minutes': 4.0,
#   'seconds': 53.039999999999964,
#   'timestamp': datetime.timedelta(seconds=293, microseconds=40000)},
#  {'text': 'can hold the representation that',
#   'start': 291.0,
#   'duration': 4.86,
#   'end_time': 295.86,
#   'minutes': 4.0,
#   'seconds': 55.860000000000014,
#   'timestamp': datetime.timedelta(seconds=295, microseconds=860000)},
#  {'text': 'captures some deep wisdom about the data',
#   'start': 293.04,
#   'duration': 4.379,
#   'end_time': 297.41900000000004,
#   'minutes': 4.0,
#   'seconds': 57.41900000000004,
#   'timestamp': datetime.timedelta(seconds=297, microseconds=419000)},
#  {'text': 'it has looked at',
#   'start': 295.86,
#   'duration': 3.839,
#   'end_time': 299.699,
#   'minutes': 4.0,
#   'seconds': 59.69900000000001,
#   'timestamp': datetime.timedelta(seconds=299, microseconds=699000)},
#  {'text': "it's a lot of knobs it's a lot of knobs",
#   'start': 297.419,
#   'duration': 4.921,
#   'end_time': 302.34,
#   'minutes': 5.0,
#   'seconds': 2.339999999999975,
#   'timestamp': datetime.timedelta(seconds=302, microseconds=340000)},
#  {'text': 'and somehow you know so speaking',
#   'start': 299.699,
#   'duration': 3.661,
#   'end_time': 303.36,
#   'minutes': 5.0,
#   'seconds': 3.3600000000000136,
#   'timestamp': datetime.timedelta(seconds=303, microseconds=360000)},
#  {'text': 'concretely',
#   'start': 302.34,
#   'duration': 2.4,
#   'end_time': 304.73999999999995,
#   'minutes': 5.0,
#   'seconds': 4.739999999999952,
#   'timestamp': datetime.timedelta(seconds=304, microseconds=740000)},
#  {'text': 'um one of the neural Nets that people',
#   'start': 303.36,
#   'duration': 3.119,
#   'end_time': 306.47900000000004,
#   'minutes': 5.0,
#   'seconds': 6.479000000000042,
#   'timestamp': datetime.timedelta(seconds=306, microseconds=479000)},
#  {'text': 'are very excited about right now are are',
#   'start': 304.74,
#   'duration': 4.2,
#   'end_time': 308.94,
#   'minutes': 5.0,
#   'seconds': 8.939999999999998,
#   'timestamp': datetime.timedelta(seconds=308, microseconds=940000)},
#  {'text': 'gpts which are basically just next word',
#   'start': 306.479,
#   'duration': 5.28,
#   'end_time': 311.75899999999996,
#   'minutes': 5.0,
#   'seconds': 11.758999999999958,
#   'timestamp': datetime.timedelta(seconds=311, microseconds=759000)},
#  {'text': 'prediction networks so you consume a',
#   'start': 308.94,
#   'duration': 4.979,
#   'end_time': 313.919,
#   'minutes': 5.0,
#   'seconds': 13.918999999999983,
#   'timestamp': datetime.timedelta(seconds=313, microseconds=919000)},
#  {'text': 'sequence of words from the internet and',
#   'start': 311.759,
#   'duration': 5.401,
#   'end_time': 317.16,
#   'minutes': 5.0,
#   'seconds': 17.160000000000025,
#   'timestamp': datetime.timedelta(seconds=317, microseconds=160000)},
#  {'text': 'you try to predict the next word and uh',
#   'start': 313.919,
#   'duration': 5.28,
#   'end_time': 319.19899999999996,
#   'minutes': 5.0,
#   'seconds': 19.198999999999955,
#   'timestamp': datetime.timedelta(seconds=319, microseconds=199000)},
#  {'text': 'once you train these on a large enough',
#   'start': 317.16,
#   'duration': 3.18,
#   'end_time': 320.34000000000003,
#   'minutes': 5.0,
#   'seconds': 20.340000000000032,
#   'timestamp': datetime.timedelta(seconds=320, microseconds=340000)},
#  {'text': 'data set',
#   'start': 319.199,
#   'duration': 4.321,
#   'end_time': 323.52000000000004,
#   'minutes': 5.0,
#   'seconds': 23.52000000000004,
#   'timestamp': datetime.timedelta(seconds=323, microseconds=520000)},
#  {'text': 'um they you can basically uh prompt',
#   'start': 320.34,
#   'duration': 4.5,
#   'end_time': 324.84,
#   'minutes': 5.0,
#   'seconds': 24.839999999999975,
#   'timestamp': datetime.timedelta(seconds=324, microseconds=840000)},
#  {'text': 'these neural amounts in arbitrary ways',
#   'start': 323.52,
#   'duration': 2.459,
#   'end_time': 325.979,
#   'minutes': 5.0,
#   'seconds': 25.978999999999985,
#   'timestamp': datetime.timedelta(seconds=325, microseconds=979000)},
#  {'text': 'and you can ask them to solve problems',
#   'start': 324.84,
#   'duration': 3.359,
#   'end_time': 328.19899999999996,
#   'minutes': 5.0,
#   'seconds': 28.198999999999955,
#   'timestamp': datetime.timedelta(seconds=328, microseconds=199000)},
#  {'text': 'and they will so you can just tell them',
#   'start': 325.979,
#   'duration': 3.961,
#   'end_time': 329.94,
#   'minutes': 5.0,
#   'seconds': 29.939999999999998,
#   'timestamp': datetime.timedelta(seconds=329, microseconds=940000)},
#  {'text': "you can you can make it look like you're",
#   'start': 328.199,
#   'duration': 3.601,
#   'end_time': 331.8,
#   'minutes': 5.0,
#   'seconds': 31.80000000000001,
#   'timestamp': datetime.timedelta(seconds=331, microseconds=800000)},
#  {'text': 'trying to um',
#   'start': 329.94,
#   'duration': 3.24,
#   'end_time': 333.18,
#   'minutes': 5.0,
#   'seconds': 33.18000000000001,
#   'timestamp': datetime.timedelta(seconds=333, microseconds=180000)},
#  {'text': 'solve some kind of a mathematical',
#   'start': 331.8,
#   'duration': 2.82,
#   'end_time': 334.62,
#   'minutes': 5.0,
#   'seconds': 34.620000000000005,
#   'timestamp': datetime.timedelta(seconds=334, microseconds=620000)},
#  {'text': 'problem and they will continue what they',
#   'start': 333.18,
#   'duration': 2.7,
#   'end_time': 335.88,
#   'minutes': 5.0,
#   'seconds': 35.879999999999995,
#   'timestamp': datetime.timedelta(seconds=335, microseconds=880000)},
#  {'text': 'think is the solution based on what',
#   'start': 334.62,
#   'duration': 2.94,
#   'end_time': 337.56,
#   'minutes': 5.0,
#   'seconds': 37.56,
#   'timestamp': datetime.timedelta(seconds=337, microseconds=560000)},
#  {'text': "they've seen on the internet and very",
#   'start': 335.88,
#   'duration': 3.24,
#   'end_time': 339.12,
#   'minutes': 5.0,
#   'seconds': 39.120000000000005,
#   'timestamp': datetime.timedelta(seconds=339, microseconds=120000)},
#  {'text': 'often those Solutions look very',
#   'start': 337.56,
#   'duration': 3.84,
#   'end_time': 341.4,
#   'minutes': 5.0,
#   'seconds': 41.39999999999998,
#   'timestamp': datetime.timedelta(seconds=341, microseconds=400000)},
#  {'text': 'remarkably consistent look correct',
#   'start': 339.12,
#   'duration': 3.72,
#   'end_time': 342.84000000000003,
#   'minutes': 5.0,
#   'seconds': 42.84000000000003,
#   'timestamp': datetime.timedelta(seconds=342, microseconds=840000)},
#  {'text': 'potentially',
#   'start': 341.4,
#   'duration': 3.72,
#   'end_time': 345.12,
#   'minutes': 5.0,
#   'seconds': 45.120000000000005,
#   'timestamp': datetime.timedelta(seconds=345, microseconds=120000)},
#  {'text': 'do you still think about the brain side',
#   'start': 342.84,
#   'duration': 4.32,
#   'end_time': 347.15999999999997,
#   'minutes': 5.0,
#   'seconds': 47.15999999999997,
#   'timestamp': datetime.timedelta(seconds=347, microseconds=160000)},
#  {'text': 'of it so as neural Nets is an',
#   'start': 345.12,
#   'duration': 3.48,
#   'end_time': 348.6,
#   'minutes': 5.0,
#   'seconds': 48.60000000000002,
#   'timestamp': datetime.timedelta(seconds=348, microseconds=600000)},
#  {'text': 'abstraction or mathematical abstraction',
#   'start': 347.16,
#   'duration': 5.16,
#   'end_time': 352.32000000000005,
#   'minutes': 5.0,
#   'seconds': 52.32000000000005,
#   'timestamp': datetime.timedelta(seconds=352, microseconds=320000)},
#  {'text': 'of the brain you still draw wisdom',
#   'start': 348.6,
#   'duration': 7.56,
#   'end_time': 356.16,
#   'minutes': 5.0,
#   'seconds': 56.160000000000025,
#   'timestamp': datetime.timedelta(seconds=356, microseconds=160000)},
#  {'text': 'from from the biological neural networks',
#   'start': 352.32,
#   'duration': 5.939,
#   'end_time': 358.259,
#   'minutes': 5.0,
#   'seconds': 58.259000000000015,
#   'timestamp': datetime.timedelta(seconds=358, microseconds=259000)},
#  {'text': "or even the bigger question so you're a",
#   'start': 356.16,
#   'duration': 3.96,
#   'end_time': 360.12,
#   'minutes': 6.0,
#   'seconds': 0.12000000000000455,
#   'timestamp': datetime.timedelta(seconds=360, microseconds=120000)},
#  {'text': 'big fan of biology and biological',
#   'start': 358.259,
#   'duration': 3.901,
#   'end_time': 362.16,
#   'minutes': 6.0,
#   'seconds': 2.160000000000025,
#   'timestamp': datetime.timedelta(seconds=362, microseconds=160000)},
#  {'text': 'computation',
#   'start': 360.12,
#   'duration': 4.68,
#   'end_time': 364.8,
#   'minutes': 6.0,
#   'seconds': 4.800000000000011,
#   'timestamp': datetime.timedelta(seconds=364, microseconds=800000)},
#  {'text': 'what impressive thing is biology do',
#   'start': 362.16,
#   'duration': 5.58,
#   'end_time': 367.74,
#   'minutes': 6.0,
#   'seconds': 7.740000000000009,
#   'timestamp': datetime.timedelta(seconds=367, microseconds=740000)},
#  {'text': 'doing to you that computers are not yet',
#   'start': 364.8,
#   'duration': 5.82,
#   'end_time': 370.62,
#   'minutes': 6.0,
#   'seconds': 10.620000000000005,
#   'timestamp': datetime.timedelta(seconds=370, microseconds=620000)},
#  {'text': "that Gap I would say I'm definitely on",
#   'start': 367.74,
#   'duration': 4.56,
#   'end_time': 372.3,
#   'minutes': 6.0,
#   'seconds': 12.300000000000011,
#   'timestamp': datetime.timedelta(seconds=372, microseconds=300000)},
#  {'text': "I'm much more hesitant with the",
#   'start': 370.62,
#   'duration': 3.419,
#   'end_time': 374.039,
#   'minutes': 6.0,
#   'seconds': 14.038999999999987,
#   'timestamp': datetime.timedelta(seconds=374, microseconds=39000)},
#  {'text': 'analogies to the brain than I think you',
#   'start': 372.3,
#   'duration': 3.42,
#   'end_time': 375.72,
#   'minutes': 6.0,
#   'seconds': 15.720000000000027,
#   'timestamp': datetime.timedelta(seconds=375, microseconds=720000)},
#  {'text': 'would see potentially in the field',
#   'start': 374.039,
#   'duration': 4.321,
#   'end_time': 378.36,
#   'minutes': 6.0,
#   'seconds': 18.360000000000014,
#   'timestamp': datetime.timedelta(seconds=378, microseconds=360000)},
#  {'text': 'um and I kind of feel like',
#   'start': 375.72,
#   'duration': 5.039,
#   'end_time': 380.759,
#   'minutes': 6.0,
#   'seconds': 20.759000000000015,
#   'timestamp': datetime.timedelta(seconds=380, microseconds=759000)},
#  {'text': 'certainly the way neural network started',
#   'start': 378.36,
#   'duration': 4.74,
#   'end_time': 383.1,
#   'minutes': 6.0,
#   'seconds': 23.100000000000023,
#   'timestamp': datetime.timedelta(seconds=383, microseconds=100000)},
#  {'text': 'is everything stemmed from inspiration',
#   'start': 380.759,
#   'duration': 4.321,
#   'end_time': 385.08000000000004,
#   'minutes': 6.0,
#   'seconds': 25.08000000000004,
#   'timestamp': datetime.timedelta(seconds=385, microseconds=80000)},
#  {'text': 'by the brain but at the end of the day',
#   'start': 383.1,
#   'duration': 3.42,
#   'end_time': 386.52000000000004,
#   'minutes': 6.0,
#   'seconds': 26.52000000000004,
#   'timestamp': datetime.timedelta(seconds=386, microseconds=520000)},
#  {'text': 'the artifacts that you get after',
#   'start': 385.08,
#   'duration': 3.839,
#   'end_time': 388.919,
#   'minutes': 6.0,
#   'seconds': 28.918999999999983,
#   'timestamp': datetime.timedelta(seconds=388, microseconds=919000)},
#  {'text': 'training they are arrived at by a very',
#   'start': 386.52,
#   'duration': 3.78,
#   'end_time': 390.29999999999995,
#   'minutes': 6.0,
#   'seconds': 30.299999999999955,
#   'timestamp': datetime.timedelta(seconds=390, microseconds=300000)},
#  {'text': 'different optimization process than the',
#   'start': 388.919,
#   'duration': 3.0,
#   'end_time': 391.919,
#   'minutes': 6.0,
#   'seconds': 31.918999999999983,
#   'timestamp': datetime.timedelta(seconds=391, microseconds=919000)},
#  {'text': 'optimization process that gave rise to',
#   'start': 390.3,
#   'duration': 4.619,
#   'end_time': 394.919,
#   'minutes': 6.0,
#   'seconds': 34.91899999999998,
#   'timestamp': datetime.timedelta(seconds=394, microseconds=919000)},
#  {'text': 'the brain and so I think uh',
#   'start': 391.919,
#   'duration': 4.861,
#   'end_time': 396.78,
#   'minutes': 6.0,
#   'seconds': 36.77999999999997,
#   'timestamp': datetime.timedelta(seconds=396, microseconds=780000)},
#  {'text': 'I kind of think of it as a very',
#   'start': 394.919,
#   'duration': 3.84,
#   'end_time': 398.75899999999996,
#   'minutes': 6.0,
#   'seconds': 38.75899999999996,
#   'timestamp': datetime.timedelta(seconds=398, microseconds=759000)},
#  {'text': 'complicated alien artifact',
#   'start': 396.78,
#   'duration': 3.479,
#   'end_time': 400.25899999999996,
#   'minutes': 6.0,
#   'seconds': 40.25899999999996,
#   'timestamp': datetime.timedelta(seconds=400, microseconds=259000)},
#  {'text': "um it's something different I'm not",
#   'start': 398.759,
#   'duration': 2.821,
#   'end_time': 401.58000000000004,
#   'minutes': 6.0,
#   'seconds': 41.58000000000004,
#   'timestamp': datetime.timedelta(seconds=401, microseconds=580000)},
#  {'text': "sorry the uh the neuralness that we're",
#   'start': 400.259,
#   'duration': 3.901,
#   'end_time': 404.16,
#   'minutes': 6.0,
#   'seconds': 44.160000000000025,
#   'timestamp': datetime.timedelta(seconds=404, microseconds=160000)},
#  {'text': 'training okay they are complicated uh',
#   'start': 401.58,
#   'duration': 4.86,
#   'end_time': 406.44,
#   'minutes': 6.0,
#   'seconds': 46.44,
#   'timestamp': datetime.timedelta(seconds=406, microseconds=440000)},
#  {'text': 'Alien artifact uh I do not make',
#   'start': 404.16,
#   'duration': 3.72,
#   'end_time': 407.88000000000005,
#   'minutes': 6.0,
#   'seconds': 47.88000000000005,
#   'timestamp': datetime.timedelta(seconds=407, microseconds=880000)},
#  {'text': 'analogies to the brain because I think',
#   'start': 406.44,
#   'duration': 3.18,
#   'end_time': 409.62,
#   'minutes': 6.0,
#   'seconds': 49.620000000000005,
#   'timestamp': datetime.timedelta(seconds=409, microseconds=620000)},
#  {'text': 'the optimization process that gave rise',
#   'start': 407.88,
#   'duration': 3.36,
#   'end_time': 411.24,
#   'minutes': 6.0,
#   'seconds': 51.24000000000001,
#   'timestamp': datetime.timedelta(seconds=411, microseconds=240000)},
#  {'text': 'to it is very different from the brain',
#   'start': 409.62,
#   'duration': 4.079,
#   'end_time': 413.699,
#   'minutes': 6.0,
#   'seconds': 53.69900000000001,
#   'timestamp': datetime.timedelta(seconds=413, microseconds=699000)},
#  {'text': 'so there was no multi-agent self-play',
#   'start': 411.24,
#   'duration': 6.36,
#   'end_time': 417.6,
#   'minutes': 6.0,
#   'seconds': 57.60000000000002,
#   'timestamp': datetime.timedelta(seconds=417, microseconds=600000)},
#  {'text': 'kind of uh setup uh and evolution it was',
#   'start': 413.699,
#   'duration': 6.0,
#   'end_time': 419.699,
#   'minutes': 6.0,
#   'seconds': 59.69900000000001,
#   'timestamp': datetime.timedelta(seconds=419, microseconds=699000)},
#  {'text': 'an optimization that is basically a what',
#   'start': 417.6,
#   'duration': 4.86,
#   'end_time': 422.46000000000004,
#   'minutes': 7.0,
#   'seconds': 2.4600000000000364,
#   'timestamp': datetime.timedelta(seconds=422, microseconds=460000)},
#  {'text': 'amounts to a compression objective on a',
#   'start': 419.699,
#   'duration': 4.44,
#   'end_time': 424.139,
#   'minutes': 7.0,
#   'seconds': 4.13900000000001,
#   'timestamp': datetime.timedelta(seconds=424, microseconds=139000)},
#  {'text': 'massive amount of data okay so',
#   'start': 422.46,
#   'duration': 3.42,
#   'end_time': 425.88,
#   'minutes': 7.0,
#   'seconds': 5.8799999999999955,
#   'timestamp': datetime.timedelta(seconds=425, microseconds=880000)},
#  {'text': 'artificial neural networks are doing',
#   'start': 424.139,
#   'duration': 2.941,
#   'end_time': 427.08,
#   'minutes': 7.0,
#   'seconds': 7.079999999999984,
#   'timestamp': datetime.timedelta(seconds=427, microseconds=80000)},
#  {'text': 'compression',
#   'start': 425.88,
#   'duration': 4.379,
#   'end_time': 430.259,
#   'minutes': 7.0,
#   'seconds': 10.259000000000015,
#   'timestamp': datetime.timedelta(seconds=430, microseconds=259000)},
#  {'text': 'and biological neural networks',
#   'start': 427.08,
#   'duration': 5.04,
#   'end_time': 432.12,
#   'minutes': 7.0,
#   'seconds': 12.120000000000005,
#   'timestamp': datetime.timedelta(seconds=432, microseconds=120000)},
#  {'text': "are not to survive and they're not",
#   'start': 430.259,
#   'duration': 3.541,
#   'end_time': 433.8,
#   'minutes': 7.0,
#   'seconds': 13.800000000000011,
#   'timestamp': datetime.timedelta(seconds=433, microseconds=800000)},
#  {'text': "really doing any they're they're an",
#   'start': 432.12,
#   'duration': 4.68,
#   'end_time': 436.8,
#   'minutes': 7.0,
#   'seconds': 16.80000000000001,
#   'timestamp': datetime.timedelta(seconds=436, microseconds=800000)},
#  {'text': 'agent in a multi-agent self-place system',
#   'start': 433.8,
#   'duration': 5.16,
#   'end_time': 438.96000000000004,
#   'minutes': 7.0,
#   'seconds': 18.960000000000036,
#   'timestamp': datetime.timedelta(seconds=438, microseconds=960000)},
#  {'text': "that's been running for a very very long",
#   'start': 436.8,
#   'duration': 4.799,
#   'end_time': 441.599,
#   'minutes': 7.0,
#   'seconds': 21.59899999999999,
#   'timestamp': datetime.timedelta(seconds=441, microseconds=599000)},
#  {'text': 'time that said Evolution has found that',
#   'start': 438.96,
#   'duration': 5.88,
#   'end_time': 444.84,
#   'minutes': 7.0,
#   'seconds': 24.839999999999975,
#   'timestamp': datetime.timedelta(seconds=444, microseconds=840000)},
#  {'text': 'it is very useful to to predict and have',
#   'start': 441.599,
#   'duration': 5.461,
#   'end_time': 447.06,
#   'minutes': 7.0,
#   'seconds': 27.060000000000002,
#   'timestamp': datetime.timedelta(seconds=447, microseconds=60000)},
#  {'text': 'a predictive model in the brain and so I',
# ...
#   'end_time': 1987.1999999999998,
#   'minutes': 33.0,
#   'seconds': 7.199999999999818,
#   'timestamp': datetime.timedelta(seconds=1987, microseconds=200000)},
#  {'text': 'raise the hand I chose to do this now',
#   'start': 1983.899,
#   'duration': 5.66,
#   'end_time': 1989.559,
#   'minutes': 33.0,
#   'seconds': 9.558999999999969,
#   'timestamp': datetime.timedelta(seconds=1989, microseconds=559000)},
#  {'text': 'um what',
#   'start': 1987.2,
#   'duration': 4.8,
#   'end_time': 1992.0,
#   'minutes': 33.0,
#   'seconds': 12.0,
#   'timestamp': datetime.timedelta(seconds=1992)},
#  {'text': "that doesn't feel like a deterministic",
#   'start': 1989.559,
#   'duration': 4.781,
#   'end_time': 1994.34,
#   'minutes': 33.0,
#   'seconds': 14.339999999999918,
#   'timestamp': datetime.timedelta(seconds=1994, microseconds=340000)},
#  {'text': "thing it feels like I'm making a choice",
#   'start': 1992.0,
#   'duration': 4.559,
#   'end_time': 1996.559,
#   'minutes': 33.0,
#   'seconds': 16.55899999999997,
#   'timestamp': datetime.timedelta(seconds=1996, microseconds=559000)},
#  {'text': "it feels like it okay so it's all",
#   'start': 1994.34,
#   'duration': 5.28,
#   'end_time': 1999.62,
#   'minutes': 33.0,
#   'seconds': 19.61999999999989,
#   'timestamp': datetime.timedelta(seconds=1999, microseconds=620000)},
#  {'text': "feelings it's just feelings yeah so when",
#   'start': 1996.559,
#   'duration': 7.081,
#   'end_time': 2003.6399999999999,
#   'minutes': 33.0,
#   'seconds': 23.639999999999873,
#   'timestamp': datetime.timedelta(seconds=2003, microseconds=640000)},
#  {'text': 'an RL agent is making a choice is that',
#   'start': 1999.62,
#   'duration': 4.919,
#   'end_time': 2004.539,
#   'minutes': 33.0,
#   'seconds': 24.538999999999987,
#   'timestamp': datetime.timedelta(seconds=2004, microseconds=539000)},
#  {'text': 'um',
#   'start': 2003.64,
#   'duration': 2.519,
#   'end_time': 2006.159,
#   'minutes': 33.0,
#   'seconds': 26.159000000000106,
#   'timestamp': datetime.timedelta(seconds=2006, microseconds=159000)},
#  {'text': "it's not really making a choice the",
#   'start': 2004.539,
#   'duration': 3.421,
#   'end_time': 2007.96,
#   'minutes': 33.0,
#   'seconds': 27.960000000000036,
#   'timestamp': datetime.timedelta(seconds=2007, microseconds=960000)},
#  {'text': 'choices are all already there yeah',
#   'start': 2006.159,
#   'duration': 2.941,
#   'end_time': 2009.1000000000001,
#   'minutes': 33.0,
#   'seconds': 29.100000000000136,
#   'timestamp': datetime.timedelta(seconds=2009, microseconds=100000)},
#  {'text': "you're interpreting the choice and",
#   'start': 2007.96,
#   'duration': 3.059,
#   'end_time': 2011.019,
#   'minutes': 33.0,
#   'seconds': 31.019000000000005,
#   'timestamp': datetime.timedelta(seconds=2011, microseconds=19000)},
#  {'text': "you're creating a narrative for or",
#   'start': 2009.1,
#   'duration': 3.84,
#   'end_time': 2012.9399999999998,
#   'minutes': 33.0,
#   'seconds': 32.93999999999983,
#   'timestamp': datetime.timedelta(seconds=2012, microseconds=940000)},
#  {'text': "having made it yeah and now we're",
#   'start': 2011.019,
#   'duration': 3.241,
#   'end_time': 2014.26,
#   'minutes': 33.0,
#   'seconds': 34.25999999999999,
#   'timestamp': datetime.timedelta(seconds=2014, microseconds=260000)},
#  {'text': "talking about the narrative it's very",
#   'start': 2012.94,
#   'duration': 4.32,
#   'end_time': 2017.26,
#   'minutes': 33.0,
#   'seconds': 37.25999999999999,
#   'timestamp': datetime.timedelta(seconds=2017, microseconds=260000)},
#  {'text': 'meta looking back what is the most',
#   'start': 2014.26,
#   'duration': 5.1,
#   'end_time': 2019.36,
#   'minutes': 33.0,
#   'seconds': 39.3599999999999,
#   'timestamp': datetime.timedelta(seconds=2019, microseconds=360000)},
#  {'text': 'beautiful or surprising idea in deep',
#   'start': 2017.26,
#   'duration': 5.039,
#   'end_time': 2022.299,
#   'minutes': 33.0,
#   'seconds': 42.29899999999998,
#   'timestamp': datetime.timedelta(seconds=2022, microseconds=299000)},
#  {'text': "learning or AI in general that you've",
#   'start': 2019.36,
#   'duration': 4.919,
#   'end_time': 2024.279,
#   'minutes': 33.0,
#   'seconds': 44.278999999999996,
#   'timestamp': datetime.timedelta(seconds=2024, microseconds=279000)},
#  {'text': "come across you've seen this field",
#   'start': 2022.299,
#   'duration': 3.36,
#   'end_time': 2025.6589999999999,
#   'minutes': 33.0,
#   'seconds': 45.65899999999988,
#   'timestamp': datetime.timedelta(seconds=2025, microseconds=659000)},
#  {'text': 'explode',
#   'start': 2024.279,
#   'duration': 4.62,
#   'end_time': 2028.899,
#   'minutes': 33.0,
#   'seconds': 48.89899999999989,
#   'timestamp': datetime.timedelta(seconds=2028, microseconds=899000)},
#  {'text': 'and grow in interesting ways just what',
#   'start': 2025.659,
#   'duration': 5.941,
#   'end_time': 2031.6000000000001,
#   'minutes': 33.0,
#   'seconds': 51.600000000000136,
#   'timestamp': datetime.timedelta(seconds=2031, microseconds=600000)},
#  {'text': 'what cool ideas like like we made you',
#   'start': 2028.899,
#   'duration': 6.421,
#   'end_time': 2035.32,
#   'minutes': 33.0,
#   'seconds': 55.319999999999936,
#   'timestamp': datetime.timedelta(seconds=2035, microseconds=320000)},
#  {'text': 'sit back and go hmm small big or small',
#   'start': 2031.6,
#   'duration': 4.98,
#   'end_time': 2036.58,
#   'minutes': 33.0,
#   'seconds': 56.57999999999993,
#   'timestamp': datetime.timedelta(seconds=2036, microseconds=580000)},
#  {'text': "well the one that I've been thinking",
#   'start': 2035.32,
#   'duration': 5.16,
#   'end_time': 2040.48,
#   'minutes': 34.0,
#   'seconds': 0.4800000000000182,
#   'timestamp': datetime.timedelta(seconds=2040, microseconds=480000)},
#  {'text': 'about recently the most probably is the',
#   'start': 2036.58,
#   'duration': 6.12,
#   'end_time': 2042.6999999999998,
#   'minutes': 34.0,
#   'seconds': 2.699999999999818,
#   'timestamp': datetime.timedelta(seconds=2042, microseconds=700000)},
#  {'text': 'the Transformer architecture',
#   'start': 2040.48,
#   'duration': 5.22,
#   'end_time': 2045.7,
#   'minutes': 34.0,
#   'seconds': 5.7000000000000455,
#   'timestamp': datetime.timedelta(seconds=2045, microseconds=700000)},
#  {'text': 'um so basically uh neural networks have',
#   'start': 2042.7,
#   'duration': 5.219,
#   'end_time': 2047.919,
#   'minutes': 34.0,
#   'seconds': 7.919000000000096,
#   'timestamp': datetime.timedelta(seconds=2047, microseconds=919000)},
#  {'text': 'a lot of architectures that were trendy',
#   'start': 2045.7,
#   'duration': 4.56,
#   'end_time': 2050.26,
#   'minutes': 34.0,
#   'seconds': 10.260000000000218,
#   'timestamp': datetime.timedelta(seconds=2050, microseconds=260000)},
#  {'text': 'have come and gone for different sensory',
#   'start': 2047.919,
#   'duration': 4.5,
#   'end_time': 2052.419,
#   'minutes': 34.0,
#   'seconds': 12.418999999999869,
#   'timestamp': datetime.timedelta(seconds=2052, microseconds=419000)},
#  {'text': 'modalities like for Vision Audio text',
#   'start': 2050.26,
#   'duration': 3.48,
#   'end_time': 2053.7400000000002,
#   'minutes': 34.0,
#   'seconds': 13.740000000000236,
#   'timestamp': datetime.timedelta(seconds=2053, microseconds=740000)},
#  {'text': 'you would process them with different',
#   'start': 2052.419,
#   'duration': 3.18,
#   'end_time': 2055.5989999999997,
#   'minutes': 34.0,
#   'seconds': 15.598999999999705,
#   'timestamp': datetime.timedelta(seconds=2055, microseconds=599000)},
#  {'text': "looking neural nuts and recently we've",
#   'start': 2053.74,
#   'duration': 3.72,
#   'end_time': 2057.4599999999996,
#   'minutes': 34.0,
#   'seconds': 17.45999999999958,
#   'timestamp': datetime.timedelta(seconds=2057, microseconds=460000)},
#  {'text': 'seen these convergence towards one',
#   'start': 2055.599,
#   'duration': 4.441,
#   'end_time': 2060.04,
#   'minutes': 34.0,
#   'seconds': 20.039999999999964,
#   'timestamp': datetime.timedelta(seconds=2060, microseconds=40000)},
#  {'text': 'architecture the Transformer and you can',
#   'start': 2057.46,
#   'duration': 4.56,
#   'end_time': 2062.02,
#   'minutes': 34.0,
#   'seconds': 22.019999999999982,
#   'timestamp': datetime.timedelta(seconds=2062, microseconds=20000)},
#  {'text': 'feed it video or you can feed it you',
#   'start': 2060.04,
#   'duration': 3.66,
#   'end_time': 2063.7,
#   'minutes': 34.0,
#   'seconds': 23.699999999999818,
#   'timestamp': datetime.timedelta(seconds=2063, microseconds=700000)},
#  {'text': 'know images or speech or text and it',
#   'start': 2062.02,
#   'duration': 3.359,
#   'end_time': 2065.379,
#   'minutes': 34.0,
#   'seconds': 25.378999999999905,
#   'timestamp': datetime.timedelta(seconds=2065, microseconds=379000)},
#  {'text': "just gobbles it up and it's kind of like",
#   'start': 2063.7,
#   'duration': 4.8,
#   'end_time': 2068.5,
#   'minutes': 34.0,
#   'seconds': 28.5,
#   'timestamp': datetime.timedelta(seconds=2068, microseconds=500000)},
#  {'text': 'a bit of a general purpose uh computer',
#   'start': 2065.379,
#   'duration': 4.8,
#   'end_time': 2070.179,
#   'minutes': 34.0,
#   'seconds': 30.179000000000087,
#   'timestamp': datetime.timedelta(seconds=2070, microseconds=179000)},
#  {'text': 'that is also trainable and very',
#   'start': 2068.5,
#   'duration': 3.3,
#   'end_time': 2071.8,
#   'minutes': 34.0,
#   'seconds': 31.800000000000182,
#   'timestamp': datetime.timedelta(seconds=2071, microseconds=800000)},
#  {'text': 'efficient to run on our Hardware',
#   'start': 2070.179,
#   'duration': 5.641,
#   'end_time': 2075.82,
#   'minutes': 34.0,
#   'seconds': 35.820000000000164,
#   'timestamp': datetime.timedelta(seconds=2075, microseconds=820000)},
#  {'text': 'and so uh this paper came out in 2016 I',
#   'start': 2071.8,
#   'duration': 4.98,
#   'end_time': 2076.78,
#   'minutes': 34.0,
#   'seconds': 36.7800000000002,
#   'timestamp': datetime.timedelta(seconds=2076, microseconds=780000)},
#  {'text': 'want to say',
#   'start': 2075.82,
#   'duration': 2.519,
#   'end_time': 2078.339,
#   'minutes': 34.0,
#   'seconds': 38.33899999999994,
#   'timestamp': datetime.timedelta(seconds=2078, microseconds=339000)},
#  {'text': 'um attention is all you need attention',
#   'start': 2076.78,
#   'duration': 3.66,
#   'end_time': 2080.44,
#   'minutes': 34.0,
#   'seconds': 40.440000000000055,
#   'timestamp': datetime.timedelta(seconds=2080, microseconds=440000)},
#  {'text': 'is all you need you criticize the paper',
#   'start': 2078.339,
#   'duration': 5.58,
#   'end_time': 2083.919,
#   'minutes': 34.0,
#   'seconds': 43.91899999999987,
#   'timestamp': datetime.timedelta(seconds=2083, microseconds=919000)},
#  {'text': "title in retrospect that it wasn't",
#   'start': 2080.44,
#   'duration': 6.84,
#   'end_time': 2087.28,
#   'minutes': 34.0,
#   'seconds': 47.2800000000002,
#   'timestamp': datetime.timedelta(seconds=2087, microseconds=280000)},
#  {'text': "um it didn't foresee the bigness of the",
#   'start': 2083.919,
#   'duration': 4.98,
#   'end_time': 2088.899,
#   'minutes': 34.0,
#   'seconds': 48.89899999999989,
#   'timestamp': datetime.timedelta(seconds=2088, microseconds=899000)},
#  {'text': 'impact yeah that it was going to have',
#   'start': 2087.28,
#   'duration': 2.819,
#   'end_time': 2090.099,
#   'minutes': 34.0,
#   'seconds': 50.09900000000016,
#   'timestamp': datetime.timedelta(seconds=2090, microseconds=99000)},
#  {'text': "yeah I'm not sure if the authors were",
#   'start': 2088.899,
#   'duration': 2.94,
#   'end_time': 2091.839,
#   'minutes': 34.0,
#   'seconds': 51.83899999999994,
#   'timestamp': datetime.timedelta(seconds=2091, microseconds=839000)},
#  {'text': 'aware of the impact that that paper',
#   'start': 2090.099,
#   'duration': 3.121,
#   'end_time': 2093.2200000000003,
#   'minutes': 34.0,
#   'seconds': 53.220000000000255,
#   'timestamp': datetime.timedelta(seconds=2093, microseconds=220000)},
#  {'text': 'would go on to have probably they',
#   'start': 2091.839,
#   'duration': 3.481,
#   'end_time': 2095.32,
#   'minutes': 34.0,
#   'seconds': 55.320000000000164,
#   'timestamp': datetime.timedelta(seconds=2095, microseconds=320000)},
#  {'text': "weren't but I think they were aware of",
#   'start': 2093.22,
#   'duration': 3.6,
#   'end_time': 2096.8199999999997,
#   'minutes': 34.0,
#   'seconds': 56.81999999999971,
#   'timestamp': datetime.timedelta(seconds=2096, microseconds=820000)},
#  {'text': 'some of the motivations and design',
#   'start': 2095.32,
#   'duration': 3.0,
#   'end_time': 2098.32,
#   'minutes': 34.0,
#   'seconds': 58.320000000000164,
#   'timestamp': datetime.timedelta(seconds=2098, microseconds=320000)},
#  {'text': 'decisions beyond the Transformer and',
#   'start': 2096.82,
#   'duration': 3.539,
#   'end_time': 2100.3590000000004,
#   'minutes': 35.0,
#   'seconds': 0.35900000000037835,
#   'timestamp': datetime.timedelta(seconds=2100, microseconds=359000)},
#  {'text': 'they chose not to I think expand on it',
#   'start': 2098.32,
#   'duration': 4.019,
#   'end_time': 2102.339,
#   'minutes': 35.0,
#   'seconds': 2.338999999999942,
#   'timestamp': datetime.timedelta(seconds=2102, microseconds=339000)},
#  {'text': 'in that way in the paper and so I think',
#   'start': 2100.359,
#   'duration': 4.381,
#   'end_time': 2104.74,
#   'minutes': 35.0,
#   'seconds': 4.739999999999782,
#   'timestamp': datetime.timedelta(seconds=2104, microseconds=740000)},
#  {'text': 'they had an idea that there was more',
#   'start': 2102.339,
#   'duration': 4.741,
#   'end_time': 2107.08,
#   'minutes': 35.0,
#   'seconds': 7.079999999999927,
#   'timestamp': datetime.timedelta(seconds=2107, microseconds=80000)},
#  {'text': 'um than just the surface of just like oh',
#   'start': 2104.74,
#   'duration': 3.54,
#   'end_time': 2108.2799999999997,
#   'minutes': 35.0,
#   'seconds': 8.279999999999745,
#   'timestamp': datetime.timedelta(seconds=2108, microseconds=280000)},
#  {'text': "we're just doing translation and here's",
#   'start': 2107.08,
#   'duration': 2.46,
#   'end_time': 2109.54,
#   'minutes': 35.0,
#   'seconds': 9.539999999999964,
#   'timestamp': datetime.timedelta(seconds=2109, microseconds=540000)},
#  {'text': "a better architecture you're not just",
#   'start': 2108.28,
#   'duration': 2.7,
#   'end_time': 2110.98,
#   'minutes': 35.0,
#   'seconds': 10.980000000000018,
#   'timestamp': datetime.timedelta(seconds=2110, microseconds=980000)},
#  {'text': 'doing translation this is like a really',
#   'start': 2109.54,
#   'duration': 3.24,
#   'end_time': 2112.7799999999997,
#   'minutes': 35.0,
#   'seconds': 12.779999999999745,
#   'timestamp': datetime.timedelta(seconds=2112, microseconds=780000)},
#  {'text': 'cool differentiable optimizable',
#   'start': 2110.98,
#   'duration': 3.48,
#   'end_time': 2114.46,
#   'minutes': 35.0,
#   'seconds': 14.460000000000036,
#   'timestamp': datetime.timedelta(seconds=2114, microseconds=460000)},
#  {'text': "efficient computer that you've proposed",
#   'start': 2112.78,
#   'duration': 3.66,
#   'end_time': 2116.44,
#   'minutes': 35.0,
#   'seconds': 16.440000000000055,
#   'timestamp': datetime.timedelta(seconds=2116, microseconds=440000)},
#  {'text': "and maybe they didn't have all of that",
#   'start': 2114.46,
#   'duration': 3.18,
#   'end_time': 2117.64,
#   'minutes': 35.0,
#   'seconds': 17.639999999999873,
#   'timestamp': datetime.timedelta(seconds=2117, microseconds=640000)},
#  {'text': 'foresight but I think is really',
#   'start': 2116.44,
#   'duration': 3.0,
#   'end_time': 2119.44,
#   'minutes': 35.0,
#   'seconds': 19.440000000000055,
#   'timestamp': datetime.timedelta(seconds=2119, microseconds=440000)},
#  {'text': "interesting isn't it funny sorry to",
#   'start': 2117.64,
#   'duration': 5.1,
#   'end_time': 2122.74,
#   'minutes': 35.0,
#   'seconds': 22.73999999999978,
#   'timestamp': datetime.timedelta(seconds=2122, microseconds=740000)},
#  {'text': 'interrupt that title is memeable that',
#   'start': 2119.44,
#   'duration': 6.24,
#   'end_time': 2125.68,
#   'minutes': 35.0,
#   'seconds': 25.679999999999836,
#   'timestamp': datetime.timedelta(seconds=2125, microseconds=680000)},
#  {'text': 'they went for such a profound idea they',
#   'start': 2122.74,
#   'duration': 4.92,
#   'end_time': 2127.66,
#   'minutes': 35.0,
#   'seconds': 27.659999999999854,
#   'timestamp': datetime.timedelta(seconds=2127, microseconds=660000)},
#  {'text': "went with the I don't think anyone used",
#   'start': 2125.68,
#   'duration': 3.3,
#   'end_time': 2128.98,
#   'minutes': 35.0,
#   'seconds': 28.980000000000018,
#   'timestamp': datetime.timedelta(seconds=2128, microseconds=980000)},
#  ...]

# %%
def split_text_from_test(test, max_length=16000):
    current_length = 0
    current_chunk = []
    chunks = []
    timestamps = []

    # Idea:
    # Create a list of dict first, get end time and text content
    # Then split into chunks that match the chapter of the video

    for item in test:
        word = item['text']
        end_time = int(item['start']) + int(item['duration'])
        minutes, seconds = divmod(end_time, 60)
        end_time_formatted = f"{minutes}m {seconds}s"
        if current_length + len(word) + 1 > max_length:
            chunks.append(" ".join(current_chunk))
            current_chunk = [f'{word} ({end_time_formatted})']
            current_length = len(word) + 1
        else:
            current_chunk.append(f'{word} ({end_time_formatted})')
            timestamps.append(end_time)
            current_length += len(word) + 1

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks

split_texts = split_text_from_test(test)
split_texts
# Out:
# ["think it's possible that physics has (0m 3s) exploits and we should be trying to find (0m 4s) them arranging some kind of a crazy (0m 6s) quantum mechanical system that somehow (0m 8s) gives you buffer overflow somehow gives (0m 9s) you a rounding error in the floating (0m 13s) Point synthetic intelligences are kind (0m 14s) of like the next stage of development (0m 17s) and I don't know where it leads to like (0m 19s) at some point I suspect (0m 22s) the universe is some kind of a puzzle (0m 24s) these synthetic AIS will uncover that (0m 26s) puzzle and (0m 29s) solve it (0m 28s) the following is a conversation with (0m 33s) Andre capothy previously the director of (0m 37s) AI at Tesla and before that at open Ai (0m 41s) and Stanford he is one of the greatest (0m 44s) scientists engineers and Educators in (0m 46s) the history of artificial intelligence (0m 50s) this is the Lex Friedman podcast to (0m 51s) support it please check out our sponsors (0m 55s) and now dear friends here's Andre (0m 57s) capathi (1m 0s) what is a neural network and why does it (1m 2s) seem to uh do such a surprisingly good (1m 4s) job of learning what is a neural network (1m 8s) it's a mathematical abstraction of (1m 10s) the brain I would say that's how it was (1m 11s) originally developed (1m 13s) at the end of the day it's a (1m 14s) mathematical expression and it's a (1m 15s) fairly simple mathematical expression (1m 18s) when you get down to it it's basically a (1m 21s) sequence of Matrix multiplies which are (1m 22s) really dot products mathematically and (1m 25s) some nonlinearities thrown in and so (1m 25s) it's a very simple mathematical (1m 28s) expression and it's got knobs in it many (1m 30s) knobs many knobs and these knobs are (1m 32s) Loosely related to basically the (1m 34s) synapses in your brain they're trainable (1m 36s) they're modifiable and so the idea is (1m 37s) like we need to find the setting of The (1m 39s) Knobs that makes the neural nut do (1m 42s) whatever you want it to do like classify (1m 44s) images and so on and so there's not too (1m 46s) much mystery I would say in it like (1m 48s) um you might think that basically don't (1m 49s) want to endow it with too much meaning (1m 52s) with respect to the brain and how it (1m 53s) works it's really just a complicated (1m 55s) mathematical expression with knobs and (1m 57s) those knobs need a proper setting for it (1m 59s) to do something uh desirable yeah but (2m 1s) poetry is just the collection of letters (2m 3s) with spaces but it can make us feel a (2m 6s) certain way and in that same way when (2m 7s) you get a large number of knobs together (2m 10s) whether it's in a inside the brain or (2m 13s) inside a computer they seem to they seem (2m 15s) to surprise us with the with their power (2m 17s) yeah I think that's fair so basically (2m 20s) I'm underselling it by a lot because you (2m 22s) definitely do get very surprising (2m 25s) emergent behaviors out of these neurons (2m 26s) when they're large enough and trained on (2m 29s) complicated enough problems like say for (2m 30s) example the next uh word prediction in a (2m 33s) massive data set from the internet and (2m 35s) then these neurons take on a pretty (2m 38s) surprising magical properties yeah I (2m 38s) think it's kind of interesting how much (2m 40s) you can get out of even very simple (2m 42s) mathematical formalism when your brain (2m 45s) right now I was talking is it doing next (2m 47s) word prediction (2m 48s) or is it doing something more (2m 50s) interesting well definitely some kind of (2m 52s) a generative model that's a gpt-like and (2m 54s) prompted by you (2m 55s) um yeah so you're giving me a prompt and (2m 57s) I'm kind of like responding to it in a (2m 59s) generative way and by yourself perhaps a (3m 2s) little bit like are you adding extra (3m 4s) prompts from your own memory inside your (3m 6s) head (3m 7s) automatically feels like you're (3m 9s) referencing some kind of a declarative (3m ...
#  "be encountering bullets along the way (16m 3s) because even like tiny hydrogen atoms (16m 5s) and little particles of dust are (16m 7s) basically have like massive kinetic (16m 9s) energy at those speeds and so basically (16m 11s) you need some kind of shielding you need (16m 13s) you have all the cosmic radiation uh (16m 14s) it's just like brutal out there it's (16m 16s) really hard and so my thinking is maybe (16m 18s) Interstellar travel is just extremely (16m 20s) hard (16m 22s) to build hard (16m 26s) it feels like uh it feels like we're not (16m 28s) a billion years away from doing that it (16m 29s) just might be that it's very you have to (16m 31s) go very slowly potentially as an example (16m 33s) through space (16m 35s) um right as opposed to close the speed (16m 37s) of light so I'm suspicious basically of (16m 38s) our ability to measure life and I'm (16m 41s) suspicious of the ability to um just (16m 43s) permeate all of space in the Galaxy or (16m 44s) across galaxies and that's the only way (16m 46s) that I can certainly I can currently see (16m 48s) a way around it yeah it's kind of (16m 51s) mind-blowing to think that there's (16m 52s) trillions of intelligent alien (16m 55s) civilizations out there kind of slowly (16m 57s) traveling through space (16m 59s) to meet each other and some of them meet (17m 1s) some of them go to war some of them (17m 4s) collaborate or they're all just uh (17m 6s) independent they are all just like (17m 8s) little pockets I don't know well (17m 11s) statistically if there's like (17m 13s) if it's there's trillions of them surely (17m 14s) some of them some of the pockets are (17m 16s) close enough to get some of them happen (17m 18s) to be close yeah in the close enough to (17m 19s) see each other and then once you see (17m 23s) once you see something that is (17m 26s) definitely complex life like if we see (17m 28s) something yeah we're probably going to (17m 30s) be severe like intensely aggressively (17m 33s) motivated to figure out what the hell (17m 34s) that is and try to meet them what would (17m 38s) be your first instinct to try to like at (17m 42s) a generational level meet them or defend (17m 46s) against them or what would be your uh (17m 49s) Instinct as a president of the United (17m 50s) States (17m 52s) and the scientists (17m 53s) I don't know which hat you prefer in (17m 54s) this question (17m 57s) yeah I think the the question it's (17m 58s) really hard (17m 59s) um (18m 2s) I will say like for example for us (18m 3s) um we have lots of primitive life forms (18m 4s) on Earth (18m 6s) um next to us we have all kinds of ants (18m 8s) and everything else and we share space (18m 11s) with them and we are hesitant to impact (18m 12s) on them and to we are and we're trying (18m 15s) to protect them by default because they (18m 16s) are amazing interesting dynamical (18m 18s) systems that took a long time to evolve (18m 19s) and they are interesting and special and (18m 22s) I don't know that you want to (18m 27s) um destroy that by default and so I like (18m 29s) complex dynamical systems that took a (18m 33s) lot of time to evolve I think (18m 35s) I'd like to I like to preserve it if I (18m 37s) can afford to and I'd like to think that (18m 39s) the same would be true about uh the (18m 41s) galactic resources and that uh they (18m 42s) would think that we're kind of (18m 43s) incredible interesting story that took (18m 46s) time it took a few billion years to (18m 47s) unravel and you don't want to just (18m 49s) destroy it I could see two aliens (18m 51s) talking about Earth right now and saying (18m 54s) uh I'm I'm a big fan of complex (18m 57s) dynamical systems so I think it was a (18m 59s) value to preserve these and who (19m 1s) basically are a video game they watch or (19m 3s) show a TV show that they watch (19m 5s) yeah I think uh you would need like a (19m 7s) very good reason I think to (19m 8s) to destroy it uh like why don't we (19m 10s) destroy these ...
#  "of it trying to get energy from it we're (31m 53s) just kind of like these particles in a (31m 55s) wave that I feel like is mostly (31m 57s) deterministic and takes uh Universe from (31m 59s) some kind of a big bang to some kind of (32m 2s) a super intelligent replicator some kind (32m 5s) of a stable point in the universe given (32m 7s) these laws of physics you don't think uh (32m 10s) as Einstein said God doesn't play dice (32m 12s) so you think it's mostly deterministic (32m 13s) there's no Randomness in the thing I (32m 14s) think it's deterministic oh there's tons (32m 17s) of uh well I'm I want to be careful with (32m 19s) Randomness pseudo random yeah I don't (32m 21s) like random uh I think maybe the laws of (32m 22s) physics are deterministic (32m 25s) um yeah I think they're determinants (32m 26s) just got really uncomfortable with this (32m 28s) question (32m 30s) do you have anxiety about whether the (32m 33s) universe is random or not (32m 37s) what's there's no Randomness uh you say (32m 37s) you like Goodwill Hunting it's not your (32m 41s) fault Andre it's not it's not your fault (32m 41s) man (32m 45s) um so you don't like Randomness uh yeah (32m 47s) I think it's uh unsettling I think it's (32m 48s) a deterministic system I think that (32m 51s) things that look random like say the uh (32m 53s) collapse of the wave function Etc I (32m 54s) think they're actually deterministic (32m 56s) just entanglement uh and so on and uh (32m 57s) some kind of a Multiverse Theory (33m 0s) something something okay so why does it (33m 3s) feel like we have a free will like if I (33m 6s) raise the hand I chose to do this now (33m 8s) um what (33m 11s) that doesn't feel like a deterministic (33m 13s) thing it feels like I'm making a choice (33m 16s) it feels like it okay so it's all (33m 19s) feelings it's just feelings yeah so when (33m 23s) an RL agent is making a choice is that (33m 23s) um (33m 25s) it's not really making a choice the (33m 27s) choices are all already there yeah (33m 28s) you're interpreting the choice and (33m 30s) you're creating a narrative for or (33m 32s) having made it yeah and now we're (33m 34s) talking about the narrative it's very (33m 36s) meta looking back what is the most (33m 39s) beautiful or surprising idea in deep (33m 42s) learning or AI in general that you've (33m 43s) come across you've seen this field (33m 45s) explode (33m 48s) and grow in interesting ways just what (33m 50s) what cool ideas like like we made you (33m 54s) sit back and go hmm small big or small (33m 55s) well the one that I've been thinking (34m 0s) about recently the most probably is the (34m 2s) the Transformer architecture (34m 5s) um so basically uh neural networks have (34m 7s) a lot of architectures that were trendy (34m 9s) have come and gone for different sensory (34m 11s) modalities like for Vision Audio text (34m 13s) you would process them with different (34m 15s) looking neural nuts and recently we've (34m 16s) seen these convergence towards one (34m 19s) architecture the Transformer and you can (34m 21s) feed it video or you can feed it you (34m 23s) know images or speech or text and it (34m 25s) just gobbles it up and it's kind of like (34m 27s) a bit of a general purpose uh computer (34m 29s) that is also trainable and very (34m 31s) efficient to run on our Hardware (34m 35s) and so uh this paper came out in 2016 I (34m 35s) want to say (34m 37s) um attention is all you need attention (34m 39s) is all you need you criticize the paper (34m 43s) title in retrospect that it wasn't (34m 46s) um it didn't foresee the bigness of the (34m 47s) impact yeah that it was going to have (34m 49s) yeah I'm not sure if the authors were (34m 50s) aware of the impact that that paper (34m 53s) would go on to have probably they (34m 54s) weren't but I think they were aware of (34m 56s) some of the motivations and design (34m 58s) decisions beyond the Transformer and (34m 59s) they chose not to I think expand on it (35m  ...
#  "both across all those modalities yet so (46m 40s) I think that's what a lot of people are (46m 41s) interested in but I wonder what that (46m 43s) shared understanding of like well we (46m 45s) might call Common Sense (46m 47s) has to be learned (46m 50s) inferred in order to complete the (46m 53s) sentence correctly so maybe the fact (46m 56s) that it's implied on the internet the (46m 57s) model is going to have to learn that not (47m 1s) by reading about it by inferring it in (47m 3s) the representation so like common sense (47m 5s) just like we I don't think we learn (47m 8s) common sense like nobody says (47m 10s) tells us explicitly we just figure it (47m 12s) all out by interacting with the world (47m 15s) right so here's a model of reading about (47m 16s) the way people interact with the world (47m 18s) it might have to infer that (47m 22s) I wonder yeah uh you you briefly worked (47m 24s) on a project called the world of bits (47m 27s) training in our RL system to take (47m 28s) actions on the internet (47m 31s) versus just consuming the internet like (47m 32s) we talked about do you think there's a (47m 33s) future for that kind of system (47m 35s) interacting with the internet to help (47m 38s) the learning yes I think that's probably (47m 39s) the uh the final frontier for a lot of (47m 42s) these models because (47m 44s) um so as you mentioned I was at open AI (47m 45s) I was working on this project world of (47m 46s) bits and basically it was the idea of (47m 47s) giving neural networks access to a (47m 51s) keyboard and a mouse and the idea could (47m 54s) possibly go wrong so basically you um (47m 57s) you perceive the input of the screen (47m 58s) pixels (48m 0s) and basically the state of the computer (48m 2s) is sort of visualized for human (48m 5s) consumption in images of the web browser (48m 7s) and stuff like that and then you give (48m 7s) the neural network the ability to press (48m 10s) keyboards and use the mouse and we're (48m 11s) trying to get it to for example complete (48m 13s) bookings and you know interact with user (48m 16s) interfaces and um what did you learn (48m 17s) from that experience like what was some (48m 20s) fun stuff this is super cool idea yeah I (48m 22s) mean it's like (48m 24s) uh yeah I mean the the step between (48m 27s) Observer to actor yeah is a super (48m 29s) fascinating step yeah well the universal (48m 31s) interface in the digital realm I would (48m 34s) say and there's a universal interface in (48m 35s) like the Physical Realm which in my mind (48m 37s) is a humanoid form factor kind of thing (48m 39s) we can later talk about Optimus and so (48m 42s) on but I feel like there's a (48m 44s) they're kind of like a similar (48m 45s) philosophy in some way where the human (48m 47s) the world the physical world is designed (48m 48s) for the human form and the digital world (48m 50s) is designed for the human form of seeing (48m 53s) the screen and using keyword keyboard (48m 55s) and mouse and so as the universal (48m 58s) interface that can basically uh command (49m 0s) the digital infrastructure we've built (49m 2s) up for ourselves and so it feels like a (49m 4s) very powerful interface to to command (49m 7s) and to build on top of now to your (49m 8s) question as to like what I learned from (49m 10s) that it's interesting because the world (49m 12s) of bits was basically uh too early I (49m 14s) think at open AI at the time (49m 18s) this is around 2015 or so and the (49m 20s) Zeitgeist at that time was very (49m 21s) different in AI from the Zeitgeist today (49m 24s) at the time everyone was super excited (49m 25s) about reinforcement learning from (49m 28s) scratch this is the time of the Atari (49m 30s) paper where uh neural networks were (49m 32s) playing Atari games and beating humans (49m 36s) in some cases uh alphago and so on so (49m 37s) everyone's very excited about train (49m 38s) training neural networks from scratch (49m 40s) using reinforcement learni ...
#  "when you respond once and then it (62m 29s) like over time it gets to not be (62m 31s) sophisticated and just (62m 35s) like just talk shit (62m 38s) and okay maybe you won't get to Andre (62m 40s) but it might get to another celebrity it (62m 43s) might get into other big accounts and (62m 45s) then it'll just so with just that simple (62m 47s) goal get them to respond yeah maximize (62m 50s) the probability of actual response yeah (62m 52s) I mean you could prompt a uh powerful (62m 53s) model like this with their its opinion (62m 56s) about how to do any possible thing (62m 57s) you're interested in so they will (62m 58s) discuss they're kind of on track to (63m 1s) become these oracles I could I sort of (63m 3s) think of it that way they are oracles uh (63m 4s) currently is just text but they will (63m 5s) have calculators they will have access (63m 8s) to Google search they will have all (63m 9s) kinds of couches and gizmos they will be (63m 11s) able to operate the internet and find (63m 14s) different information and (63m 15s) um (63m 17s) yeah in some sense (63m 18s) that's kind of like currently what it (63m 19s) looks like in terms of the development (63m 21s) do you think it'll be an improvement (63m 25s) eventually over what Google is for (63m 27s) access to human knowledge like it'll be (63m 29s) a more effective search engine to access (63m 31s) human knowledge I think there's definite (63m 33s) scope in building a better search engine (63m 34s) today and I think Google they have all (63m 36s) the tools all the people they have (63m 37s) everything they need they have all the (63m 38s) puzzle pieces they have people training (63m 40s) Transformers at scale they have all the (63m 43s) data uh it's just not obvious if they (63m 45s) are capable as an organization to (63m 47s) innovate on their search engine right (63m 48s) now and if they don't someone else will (63m 50s) there's absolute scope for building a (63m 52s) significantly better search engine built (63m 53s) on these tools it's so interesting a (63m 56s) large company where the search there's (63m 58s) already an infrastructure it works as it (64m 1s) brings out a lot of money so where (64m 3s) structurally inside a company is their (64m 5s) motivation to Pivot yeah to say we're (64m 8s) going to build a new search engine yep (64m 10s) that's really hard so it's usually going (64m 13s) to come from a startup right that's um (64m 16s) that would be yeah or some other more (64m 17s) competent organization (64m 20s) um so uh I don't know so currently for (64m 23s) example maybe Bing has another shot at (64m 25s) it you know so Microsoft Edge because (64m 27s) we're talking offline (64m 29s) um I mean I definitely it's really (64m 31s) interesting because search engines used (64m 33s) to be about okay here's some query (64m 36s) here's here's here's web pages that look (64m 38s) like the stuff that you have but you (64m 40s) could just directly go to answer and (64m 41s) then have supporting evidence (64m 44s) um and these uh these models basically (64m 45s) they've read all the texts and they've (64m 47s) read all the web pages and so sometimes (64m 49s) when you see yourself going over to (64m 50s) search results and sort of getting like (64m 52s) a sense of like the average answer to (64m 53s) whatever you're interested in uh like (64m 55s) that just directly comes out you don't (64m 57s) have to do that work (64m 57s) um (65m 0s) so they're kind of like uh (65m 2s) yeah I think they have a way to this of (65m 4s) distilling all that knowledge into (65m 6s) like some level of insight basically do (65m 9s) you think of prompting as a kind of (65m 10s) teaching and learning like this whole (65m 14s) process like another layer (65m 16s) you know because maybe that's what (65m 17s) humans are we already have that (65m 21s) background model and then your the world (65m 23s) is prompting you yeah exactly I think (65m 25s) the way we are programming these (65m ...
#  "so growing that common organization was (77m 25s) pretty crazy uh but uh yeah I think it's (77m 27s) extremely interesting and part of the (77m 29s) design process very much behind the (77m 31s) autopilot as to where you use humans (77m 32s) humans are very good at certain kinds of (77m 34s) annotations they're very good for (77m 35s) example at two-dimensional annotations (77m 37s) of images they're not good at annotating (77m 40s) uh cars over time in three-dimensional (77m 42s) space very very hard and so that's why (77m 44s) we were very careful to design the tasks (77m 46s) that are easy to do for humans versus (77m 48s) things that should be left to the (77m 49s) offline tracker like maybe the maybe the (77m 51s) computer will do all the triangulation (77m 53s) and 3D reconstruction but the human will (77m 54s) say exactly these pixels of the image (77m 57s) are car exactly these pixels are human (78m 0s) and so co-designing the the data (78m 2s) annotation pipeline was very much bread (78m 4s) and butter was what I was doing daily do (78m 5s) you think there's still a lot of open (78m 7s) problems in that space (78m 12s) um just in general annotation where the (78m 13s) stuff the machines are good at machines (78m 16s) do and the humans do what they're good (78m 17s) at and there's maybe some iterative (78m 20s) process right I think to a very large (78m 22s) extent we went through a number of (78m 23s) iterations and we learned a ton about (78m 26s) how to create these data sets I'm not (78m 27s) seeing big open problems like originally (78m 30s) when I joined I was like I was really (78m 32s) not sure how this would turn out yeah (78m 33s) but by the time I left I was much more (78m 35s) secure in actually we sort of understand (78m 37s) the philosophy of how to create these (78m 38s) data sets and I was pretty comfortable (78m 41s) with where that was at the time so what (78m 45s) are strengths and limitations of cameras (78m 47s) for the driving test in your (78m 48s) understanding when you formulate the (78m 50s) driving task as a vision task with eight (78m 52s) cameras (78m 54s) you've seen that the entire you know (78m 55s) most of the history of the computer (78m 57s) vision field when it has to do with (78m 59s) neural networks what just if you step (79m 0s) back what are the strengths and (79m 4s) limitations of pixels of using pixels to (79m 6s) drive yeah pixels I think are a (79m 8s) beautiful sensory beautiful sensor I (79m 11s) would say the thing is like cameras are (79m 12s) very very cheap and they provide a ton (79m 16s) of information ton of bits uh so it's uh (79m 18s) extremely cheap sensor for a ton of bits (79m 19s) and each one of these bits as a (79m 22s) constraint on the state of the world and (79m 24s) so you get lots of megapixel images uh (79m 27s) very cheap and it just gives you all (79m 28s) these constraints for understanding (79m 29s) what's actually out there in the world (79m 31s) so vision is probably the highest (79m 33s) bandwidth sensor (79m 37s) it's a very high bandwidth sensor and um (79m 42s) I love that pixels it is a is a (79m 44s) constraint on the world This is highly (79m 46s) complex (79m 47s) uh high bandwidth constraint in the (79m 49s) world on the stage of the world that's (79m 50s) fascinating it's not just that but again (79m 53s) this real real importance of (79m 55s) it's the sensor that humans use (79m 58s) therefore everything is designed for (80m 0s) that sensor yeah the text the writing (80m 2s) the flashing signs everything is (80m 6s) designed for vision and so and you just (80m 7s) find it everywhere and so that's why (80m 9s) that is the interface you want to be in (80m 10s) um talking again about these Universal (80m 13s) interfaces and uh that's where we (80m 14s) actually want to measure the world as (80m 16s) well and then develop software uh for (80m 18s) that sensor but there's other (80m 21s) constraints on the state of the world (80m 23s) tha ...
#  "vision is necessary and then also it is (92m 36s) sufficient because it has all the (92m 37s) information that you that you need for (92m 40s) driving and humans obviously is a vision (92m 41s) to drive so it's both necessary and (92m 42s) sufficient so you want to focus (92m 43s) resources and you have to be really sure (92m 45s) if you're going to bring in other (92m 47s) sensors you could you could you could (92m 49s) add sensors to Infinity at some point (92m 51s) you need to draw the line and I think in (92m 52s) this case you have to really consider (92m 55s) the full cost of any One sensor that (92m 57s) you're adopting and do you really need (92m 59s) it and I think the answer in this case (93m 1s) is no so what do you think about the (93m 4s) idea of the that the other companies (93m 6s) are forming high resolution maps and (93m 9s) constraining heavily the geographic (93m 11s) regions in which they operate is that (93m 15s) approach not in your in your view (93m 18s) um not going to scale over time to the (93m 20s) entirety of the United States I think (93m 22s) I'll take two as you mentioned like they (93m 24s) pre-map all the environments and they (93m 25s) need to refresh the map and they have a (93m 27s) perfect centimeter level accuracy map of (93m 29s) everywhere they're going to drive it's (93m 31s) crazy how are you going to (93m 33s) when we're talking about autonomy (93m 33s) actually changing the world we're (93m 36s) talking about the deployment (93m 38s) on a on a global scale of autonomous (93m 40s) systems for transportation and if you (93m 41s) need to maintain a centimeter accurate (93m 44s) map for Earth or like for many cities (93m 46s) and keep them updated it's a huge (93m 48s) dependency that you're taking on huge (93m 48s) dependency (93m 50s) it's a massive massive dependency and (93m 52s) now you need to ask yourself do you (93m 53s) really need it (93m 55s) and humans don't need it (93m 58s) um right so it's it's very useful to (94m 0s) have a low-level map of like okay the (94m 1s) connectivity of your road you know that (94m 3s) there's a fork coming up when you drive (94m 4s) an environment you sort of have that (94m 5s) high level understanding it's like a (94m 7s) small Google Map and Tesla uses Google (94m 10s) Map like similar kind of resolution (94m 12s) information in the system but it will (94m 15s) not pre-map environments to send me a (94m 16s) level accuracy it's a crutch it's a (94m 19s) distraction it costs entropy and it (94m 21s) diffuses the team it dilutes the team (94m 22s) and you're not focusing on what's (94m 24s) actually necessary which is the computer (94m 25s) vision problem (94m 27s) what did you learn about machine (94m 30s) learning about engineering about life (94m 34s) about yourself as one human being from (94m 36s) working with Elon Musk (94m 37s) I think the most I've learned is about (94m 39s) how to sort of run organizations (94m 41s) efficiently and how to (94m 43s) create efficient organizations and how (94m 46s) to fight entropy in an organization so (94m 47s) human Engineering in the fight against (94m 50s) entropy yeah there's a there's a I think (94m 53s) Elon is a very efficient warrior in the (94m 55s) fight against entropy in organizations (94m 56s) what is the entropy in an organization (95m 0s) look like exactly it's process it's (95m 4s) it's process and inefficiencies and that (95m 7s) kind of stuff yeah meetings he hates (95m 8s) meetings he keeps telling people to skip (95m 10s) meetings if they're not useful (95m 11s) um he basically runs the world's biggest (95m 15s) uh startups I would say uh Tesla SpaceX (95m 17s) are the world's biggest startups Tesla (95m 19s) actually has multiple startups I think (95m 20s) it's better to look at it that way and (95m 23s) so I think he's he's extremely good at (95m 26s) uh at that and uh yeah he's a very good (95m 27s) intuition for streamline processes (95m 30s) making everything efficient uh best ...
#  "you didn't even tweet or mention the (108m 23s) Godfather yeah I don't love that movie I (108m 26s) know it hasn't edit that out we're gonna (108m 27s) edit out the hate towards the Godfather (108m 30s) how dare you just I think I will make a (108m 31s) strong statement I don't know why I (108m 33s) don't know why but I basically don't (108m 37s) like any movie before 1995 (108m 38s) something like that didn't you mention (108m 41s) Terminator two okay okay that's like uh (108m 44s) Terminator 2 was a little bit later 1990 (108m 47s) no I think Terminator 2 was a name I (108m 49s) like Terminator one as well so okay so (108m 50s) like a few exceptions but by and large (108m 52s) for some reason I don't like movies (108m 55s) before 1995 or something they feel very (108m 57s) slow the camera is like zoomed out it's (109m 0s) boring it's kind of naive it's kind of (109m 2s) weird and also Terminator was very much (109m 4s) ahead of its time yes and The Godfather (109m 5s) there's like no AGI (109m 9s) [Laughter] (109m 11s) I mean but you have Good Will Hunting (109m 13s) was one of the movies you mentioned and (109m 15s) that doesn't have any AGI either I guess (109m 17s) that's mathematics yeah I guess (109m 19s) occasionally I do enjoy movies that (109m 21s) don't feature or like Anchorman that has (109m 24s) no that's the increment it's so good I (109m 27s) don't understand (109m 28s) um speaking of AGI because I don't (109m 31s) understand why Will Ferrell is so funny (109m 33s) it doesn't make sense it doesn't compute (109m 35s) there's just something about him and (109m 36s) he's a singular human because you don't (109m 38s) get that many comedies (109m 40s) these days and I wonder if it has to do (109m 43s) about the culture uh or the like the (109m 45s) machine of Hollywood or does it have to (109m 46s) do with just we got lucky with certain (109m 48s) people and comedy it came together (109m 51s) because he is a singular human (109m 54s) that was a ridiculous tangent I (109m 56s) apologize but you mentioned humanoid (109m 58s) robot so what do you think about Optimus (110m 0s) about Tesla bot do you think we'll have (110m 3s) robots in the factory in in the home in (110m 6s) 10 20 30 40 50 years yeah I think it's a (110m 7s) very hard project I think it's going to (110m 9s) take a while but who else is going to (110m 12s) build humano robots at scale yeah and I (110m 13s) think it is a very good form factor to (110m 14s) go after because like I mentioned the (110m 16s) the world is designed for humanoid form (110m 18s) factor these things would be able to (110m 20s) operate our machines they would be able (110m 21s) to sit down in chairs uh potentially (110m 24s) even drive cars uh basically the world (110m 25s) is designed for humans that's the form (110m 28s) factor you want to invest into and make (110m 30s) work over time uh I think you know (110m 31s) there's another school of thought which (110m 33s) is okay pick a problem and design a (110m 34s) robot to it but actually designing a (110m 35s) robot and getting a whole data engine (110m 37s) and everything behind it to work is (110m 39s) actually an incredibly hard problem so (110m 40s) it makes sense to go after General (110m 43s) interfaces that uh okay they are not (110m 44s) perfect for any one given task but they (110m 46s) actually have the generality of just (110m 49s) with a prompt with English able to do (110m 51s) something across and so I think it makes (110m 53s) a lot of sense to go after a general uh (110m 55s) interface (110m 58s) um in the physical world and I think (111m 0s) it's a very difficult project I think (111m 2s) it's going to take time but I see no (111m 4s) other no other company that can execute (111m 4s) on that Vision I think it's going to be (111m 7s) amazing like uh basically physical labor (111m 9s) like if you think transportation is a (111m 13s) large Market try physical labor insane (111m 15s) well but it's not just physical  ...
#  "yeah the graphics the physics and the (123m 38s) Agents that you put into the environment (123m 40s) and stuff like that yeah see I think you (123m 41s) I feel like you said that it's not that (123m 44s) important I guess for the future of AI (123m 47s) development is that is that correct to (123m 49s) interpret you that way uh I think (123m 51s) humans use uh simulators (123m 54s) for um humans use simulators and they (123m 56s) find them useful and so computers will (123m 58s) use simulators and find them useful (124m 0s) okay so you're saying it's not I I don't (124m 1s) use simulators very often I play a video (124m 3s) game every once in a while but I don't (124m 6s) think I derive any wisdom about my own (124m 8s) existence from from those video games (124m 11s) it's a momentary escape from reality (124m 13s) versus a source of wisdom about reality (124m 15s) so I don't so I think that's a very (124m 17s) polite way of saying simulation is not (124m 19s) that useful (124m 21s) yeah maybe maybe not I don't see it as (124m 24s) like a fundamental really important part (124m 25s) of like training neural Nets currently (124m 28s) uh but I think uh as neural Nets become (124m 30s) more and more powerful I think you will (124m 32s) need fewer examples to train additional (124m 35s) behaviors and uh simulation is of course (124m 37s) there's a domain Gap in a simulation (124m 38s) that's not the real world there's (124m 41s) slightly something different but uh with (124m 43s) a powerful enough neural net uh you need (124m 45s) um The Domain Gap can be bigger I think (124m 46s) because neural network will sort of (124m 47s) understand that even though it's not the (124m 49s) real world it like has all this high (124m 51s) level structure that I'm supposed to be (124m 52s) able to learn from so then you'll know (124m 53s) we'll actually (124m 57s) yeah you'll be able to Leverage (125m 0s) the synthetic data better yes by closing (125m 2s) the get better understanding in which (125m 5s) ways this is not real data exactly (125m 7s) uh right to do better questions next (125m 9s) time that was that was a question but (125m 12s) I'm just kidding all right um (125m 12s) so is it possible do you think speaking (125m 18s) of feminist to construct neural Nets and (125m 19s) training processes that require very (125m 21s) little data (125m 24s) so we've been talking about huge data (125m 26s) sets like the internet for training I (125m 28s) mean one way to say that is like you (125m 29s) said like the querying itself is another (125m 32s) level of training I guess and that (125m 35s) requires a little data yeah but do you (125m 38s) see any uh value in doing research and (125m 41s) kind of going down the direction of can (125m 44s) we use very little data to train to (125m 46s) construct a knowledge base 100 I just (125m 47s) think like at some point you need a (125m 48s) massive data set and then when you (125m 51s) pre-train your massive neural nut and (125m 52s) get something that you know is like a (125m 54s) GPT or something then you're able to be (125m 57s) very efficient at training any arbitrary (126m 1s) new task uh so a lot of these gpts you (126m 2s) know you can do tasks like sentiment (126m 4s) analysis or translation or so on just by (126m 6s) being prompted with very few examples (126m 7s) here's the kind of thing I want you to (126m 9s) do like here's an input sentence here's (126m 11s) the translation into German input (126m 13s) sentence translation to German input (126m 14s) sentence blank and the neural network (126m 16s) will complete the translation to German (126m 18s) just by looking at sort of the example (126m 19s) you've provided and so that's an example (126m 23s) of a very few shot uh learning in the (126m 24s) activations of the neural net instead of (126m 26s) the weights of the neural land and so I (126m 27s) think (126m 29s) basically uh just like humans neural (126m 31s) Nets will become very data effici ...
#  "better in my mind but it just means I (138m 28s) prefer plant-based food and raw or (138m 32s) cooked or I prefer cooked uh and blunt (138m 34s) paste so plant-based (138m 37s) oh forgive me I don't actually know how (138m 39s) wide the category of plant entails (138m 43s) Wellness just means that you're not uh (138m 46s) and you can flex and uh you just prefer (138m 48s) to eat plants and you know you're not (138m 49s) making you're not trying to influence (138m 51s) other people and if someone is you come (138m 53s) to someone's house party and they serve (138m 54s) you a stake that they're really proud of (138m 56s) you will eat it yes right it's just not (138m 57s) judgment oh that's beautiful I mean (138m 59s) that's (139m 0s) um on the flip side of that but I'm very (139m 2s) sort of flexible have you tried doing (139m 6s) one meal a day uh I have uh accidentally (139m 8s) not consistently but I've accidentally (139m 10s) had that I don't I don't like it I think (139m 12s) it makes me feel uh not good it's too (139m 14s) it's too much too much of a hit yeah and (139m 17s) uh So currently I have about two meals a (139m 19s) day 12 and six I do that non-stop I'm (139m 22s) doing it now I'm doing one meal a day (139m 23s) okay so it's interesting it's a (139m 25s) interesting feeling have you ever fasted (139m 27s) longer than a day yeah I've done a bunch (139m 28s) of water fasts because I was curious (139m 31s) what happens uh anything interesting (139m 33s) yeah I would say so I mean you know (139m 34s) what's interesting is that you're hungry (139m 36s) for two days and then starting day three (139m 40s) or so you're not hungry it's like such a (139m 40s) weird feeling because you haven't eaten (139m 42s) in a few days and you're not hungry (139m 44s) isn't that weird it's really one of the (139m 47s) many weird things about human biology is (139m 48s) figure something out it finds finds (139m 50s) another source of energy or something (139m 53s) like that or uh relaxes the system I (139m 54s) don't know how yeah the body is like (139m 56s) you're hungry you're hungry and then it (139m 57s) just gives up it's like okay I guess (139m 59s) we're fasting now there's nothing and (140m 0s) then it just kind of like focuses on (140m 3s) trying to make you not hungry uh and you (140m 5s) know not feel the the damage of that and (140m 7s) uh trying to give you some space to (140m 9s) figure out the food situation (140m 11s) so are you still to this day most (140m 15s) productive uh at night I would say I am (140m 17s) but it is really hard to maintain my PhD (140m 18s) schedule (140m 21s) um especially when I was say working at (140m 23s) Tesla and so on it's a non-starter so (140m 24s) but even now like you know people want (140m 25s) to meet for (140m 29s) various events they Society lives in a (140m 30s) certain period of time and you sort of (140m 32s) have to like work so that's it's hard to (140m 34s) like do a social thing and then after (140m 37s) that return and do work yeah it's just (140m 38s) really hard (140m 41s) uh that's why I try to do social things (140m 43s) I try not to do too uh too much drinking (140m 47s) so I can return and continue doing work (140m 49s) um but a Tesla is there is there (140m 52s) conversions in Tesla but any any company (140m 55s) is there a convergence towards the (140m 57s) schedule or is there more (140m 59s) is that how humans behave when they (141m 1s) collaborate I need to learn about this (141m 3s) yeah do they try to keep a consistent (141m 4s) schedule you're all awake at the same (141m 6s) time I mean I do try to create a routine (141m 8s) and I try to create a steady state in (141m 11s) which I'm uh comfortable in uh so I have (141m 13s) a morning routine I have a day routine I (141m 14s) try to keep things to do a steady state (141m 17s) and um things are predictable and then (141m 19s) you can sort of just like your body just (141m 21s) sort of like sticks to that and if  ...
#  "blockchains where everyone's building on (153m 21s) each other's work and setting each other (153m 24s) and you sort of have ai which is kind of (153m 25s) like this much faster and loose (153m 29s) blockchain but then you have and any one (153m 30s) individual entry is like very um very (153m 32s) cheap to make and then you have other (153m 33s) fields where maybe that model doesn't (153m 36s) make as much sense (153m 38s) um and so I think in AI at least things (153m 40s) are pretty easily verifiable and so (153m 41s) that's why when people upload papers (153m 42s) they're a really good idea and so on (153m 44s) people can try it out like the next day (153m 47s) and they can be the final Arbiter (153m 48s) whether it works or not on their problem (153m 49s) and the whole thing just moves (153m 51s) significantly faster so I kind of feel (153m 54s) like Academia still has a place sorry (153m 55s) this like conference Journal process (153m 56s) still has a place but it's sort of like (153m 59s) an um it lags behind I think and it's a (154m 2s) bit more maybe higher quality process (154m 4s) but it's not sort of the place where you (154m 6s) will discover Cutting Edge work anymore (154m 8s) yeah it used to be the case when I was (154m 8s) starting my PhD that you go to (154m 11s) conferences and journals and you discuss (154m 12s) all the latest research now when you go (154m 14s) to a conference or Journal like no one (154m 16s) discusses anything that's there because (154m 17s) it's already like three generations ago (154m 20s) irrelevant yes which makes me sad about (154m 22s) like deepmind for example where they (154m 24s) they still they still publish in nature (154m 27s) and these big prestigious I mean there's (154m 29s) still value as opposed to The Prestige (154m 31s) that comes with these big venues but the (154m 34s) the result is that they they'll announce (154m 36s) some breakthrough performance and it'll (154m 38s) take like a year to actually publish the (154m 42s) details I mean and those details in if (154m 43s) they were published immediately would (154m 45s) Inspire the community to move in certain (154m 47s) directions with that yeah it would speed (154m 48s) up the rest of the community but I don't (154m 50s) know to what extent that's part of their (154m 52s) objective function also that's true so (154m 53s) it's not just the prestige a little bit (154m 57s) of the delay is uh is part yeah they (154m 58s) certainly deepmind specifically has been (155m 1s) um working in the regime of having a (155m 2s) slightly higher quality basically (155m 4s) process and latency and uh publishing (155m 7s) those papers that way another question (155m 10s) from Reddit do you or have you suffered (155m 12s) from imposter syndrome being the (155m 16s) director of AI Tesla being this person (155m 18s) when you're at Stanford where like the (155m 20s) world looks at you as the expert in AI (155m 23s) to teach teach the world about machine (155m 26s) learning when I was leaving Tesla after (155m 28s) five years I spent a ton of time in (155m 30s) meeting rooms uh and you know I would (155m 32s) read papers in the beginning when I (155m 33s) joined Tesla I was writing code and then (155m 35s) I was writing lesson last code and I was (155m 36s) reading code and then I was reading (155m 38s) lesson less code and so this is just a (155m 39s) natural progression that happens I think (155m 41s) and uh definitely I would say near the (155m 43s) tail end that's when it sort of like (155m 44s) starts to hit you a bit more that you're (155m 46s) supposed to be an expert but actually (155m 47s) the source of Truth is the code that (155m 49s) people are writing the GitHub and the (155m 52s) actual the actual code itself and you're (155m 53s) not as familiar with that as you used to (155m 55s) be and so I would say maybe there's some (155m 56s) like insecurity there yeah that's (155m 59s) actually pretty profound that a lot of (156m 0s)  ...
#  "so it just feels like we're in again (168m 12s) boiling water we won't know as it's (168m 13s) happening (168m 17s) I would like to I'm not afraid of AGI (168m 19s) I'm excited about it there's always (168m 21s) concerns but I would like to know when (168m 22s) it happens (168m 26s) yeah or and have like hints about when (168m 28s) it happens like a year from now it will (168m 30s) happen that kind of thing yeah I just (168m 31s) feel like in the digital realm it just (168m 33s) might happen yeah I think all we have (168m 35s) available to us because no one has built (168m 38s) AGI again so all we have available to us (168m 41s) is uh is there enough for cow ground on (168m 43s) the periphery I would say yes and we (168m 44s) have the progress so far which has been (168m 47s) very rapid and uh there are next steps (168m 49s) that are available and so (168m 50s) I would say uh yeah it's quite likely (168m 52s) that we'll be interacting with digital (168m 55s) entities how will you know that (168m 57s) somebody's birthday it's going to be a (168m 58s) slow I think it's going to be a slow (168m 59s) incremental transition is going to be (169m 2s) product based and focused it's going to (169m 3s) be GitHub co-pilot getting better and (169m 6s) then uh GPT is helping you right and (169m 8s) then these oracles that you can go to (169m 9s) with mathematical problems I think we're (169m 12s) on a on the verge of being able to ask (169m 13s) very complex (169m 16s) questions in chemistry physics math of (169m 18s) these oracles and have them complete (169m 19s) Solutions (169m 21s) so AGI to use primarily focus on (169m 23s) intelligence so Consciousness doesn't (169m 24s) enter (169m 26s) into uh into it (169m 29s) so in my mind Consciousness is not a (169m 30s) special thing you will you will figure (169m 32s) out and bolt-on I think it's an emerging (169m 35s) phenomenon of a large enough and complex (169m 36s) enough (169m 39s) um generative model sort of so (169m 41s) um if you have a complex and Alpha World (169m 43s) model that understands the world then it (169m 46s) also understands its predicament in the (169m 48s) world as being a language model which to (169m 49s) me is a form of Consciousness or (169m 52s) self-awareness and so in order to (169m 53s) understand the world deeply you probably (169m 55s) have to integrate yourself into the (169m 57s) world yeah and in order to interact with (169m 59s) humans and other living beings (170m 2s) Consciousness is a very useful tool I (170m 4s) think Consciousness is like a modeling (170m 5s) insight (170m 8s) modeling Insight yeah it's a you have a (170m 10s) powerful enough model of understanding (170m 10s) the world that you actually understand (170m 13s) that you are an entity in it yeah but (170m 15s) there's also this um perhaps just a (170m 17s) narrative we tell ourselves there's a it (170m 19s) feels like something to experience the (170m 21s) world the hard problem of Consciousness (170m 23s) yeah but that could be just the (170m 25s) narrative that we tell ourselves yeah I (170m 25s) don't think what yeah I think it will (170m 27s) emerge I think it's going to be (170m 29s) something uh very boring like we'll be (170m 31s) talking to these uh digital AIS they (170m 33s) will claim they're conscious they will (170m 35s) appear conscious they will do all the (170m 36s) things that you would expect of other (170m 38s) humans and uh it's going to just be a (170m 40s) stalemate I I think there would be a lot (170m 43s) of actual fascinating ethical questions (170m 46s) like Supreme Court level questions (170m 50s) of whether you're allowed to turn off a (170m 52s) conscious AI if you're allowed to build (170m 54s) the conscious AI (170m 57s) maybe there would have to be the same (171m 0s) kind of debates that you have around (171m 2s) um sorry to bring up a political topic (171m 6s) but you know abortion which is the (171m 8s) deeper question with abortion (171m 11s) is wha ...
#  "that's a really bad position to be in a (184m 19s) tiny perturbation of the system results (184m 22s) in the destruction of the human species (184m 24s) it's a weird line to walk yeah I think (184m 26s) in general what's really weird about (184m 27s) like the Dynamics of humanity and this (184m 29s) explosion was talked about is just like (184m 31s) the insane coupling afforded by (184m 33s) technology yeah and uh just the (184m 35s) instability of the whole dynamical (184m 37s) system I think it's just it doesn't look (184m 38s) good honestly (184m 40s) yes that explosion could be destructive (184m 42s) and constructive and the probabilities (184m 45s) are non-zero in both both senses I'm (184m 46s) going to have to I do feel like I have (184m 48s) to try to be optimistic and so on and (184m 50s) yes I think even in this case I still am (184m 51s) predominantly optimistic but there's (184m 52s) definitely (184m 55s) me too uh do you think we'll become a (184m 58s) multiplayer species (184m 59s) probably yes but I don't know if it's (185m 2s) dominant feature of uh future Humanity (185m 5s) uh there might be some people on some (185m 7s) planets and so on but I'm not sure if (185m 8s) it's like (185m 10s) yeah if it's like a major player in our (185m 13s) culture and so on we still have to solve (185m 15s) the drivers of self-destruction here on (185m 17s) Earth so just having a backup on Mars is (185m 20s) not going to solve the problem so by the (185m 21s) way I love the backup on Mars I think (185m 22s) that's amazing you should absolutely do (185m 26s) that yes and I'm so thankful uh and (185m 29s) would you go to Mars uh personally no I (185m 32s) do like Earth quite a lot okay uh I'll (185m 33s) go to Mars I'll go for you unless I'll (185m 35s) tweet at you from there maybe eventually (185m 37s) I would once it's uh safe enough but I (185m 39s) don't actually know if it's on my (185m 41s) lifetime scale unless I can extend it by (185m 42s) a lot (185m 43s) I do think that for example a lot of (185m 45s) people might disappear into (185m 47s) um virtual realities and stuff like that (185m 48s) and I think that could be the major (185m 49s) thrust of (185m 50s) um sort of the cultural development of (185m 54s) humanity if it survives uh so it might (185m 55s) not be it's just really hard to work in (185m 58s) Physical Realm and go out there and I (185m 59s) think ultimately all your experiences (186m 2s) are in your brain yeah and so it's much (186m 5s) easier to disappear into digital Realm (186m 7s) and I think people will find them more (186m 9s) compelling easier safer (186m 11s) more interesting so you're a little bit (186m 12s) captivated by Virtual Reality by the (186m 14s) possible worlds whether it's the (186m 16s) metaverse or some other manifestation of (186m 17s) that yeah (186m 20s) yeah it's really interesting it's uh (186m 24s) I'm I'm interested just just talking a (186m 26s) lot to Carmack where's the (186m 28s) where's the thing that's currently (186m 30s) preventing that yeah I mean to be clear (186m 31s) I think what's interesting about the (186m 32s) future is (186m 35s) um it's not that (186m 36s) I kind of feel like (186m 37s) the variance in The Human Condition (186m 39s) grows that's the primary thing that's (186m 42s) changing it's not as much the mean of (186m 42s) the distribution it's like the variance (186m 44s) of it so there will probably be people (186m 46s) on Mars and there will be people in VR (186m 46s) and they're all people here on Earth (186m 48s) it's just like there will be so many (186m 50s) more ways of being (186m 52s) and so I kind of feel like I see it as (186m 52s) like a spreading out of a human (186m 55s) experience there's something about the (186m 56s) internet that allows you to discover (186m 58s) those little groups and you you (187m 0s) gravitate each other something about (187m 1s) your biology likes that kind of world (187m 3s) and that you find each other yeah an ...
#  "you like consuming audiobooks and and (199m 13s) podcasts and so on and here's the (199m 15s) process that achieves (199m 17s) um closer to human level performance and (199m 20s) annotation yeah well I definitely was (199m 21s) like surprised that uh transcription (199m 24s) with opening eyes whisper was working so (199m 26s) well compared to what I'm familiar with (199m 28s) from Siri and like a few other systems I (199m 31s) guess it works so well and (199m 32s) uh that's what gave me some energy to (199m 34s) like try it out and I thought it could (199m 36s) be fun to random podcasts it's kind of (199m 40s) not obvious to me why whisper is so much (199m 41s) better compared to anything else because (199m 42s) I feel like there should be a lot of (199m 43s) incentive for a lot of companies to (199m 44s) produce transcription systems and that (199m 46s) they've done so over a long time whisper (199m 48s) is not a super exotic model it's a (199m 51s) Transformer it takes smell spectrograms (199m 53s) and you know just outputs tokens of text (199m 55s) it's not crazy uh the model and (199m 57s) everything has been around for a long (199m 58s) time (200m 0s) I'm not actually 100 sure why yeah it's (200m 2s) not obvious to me either it makes me (200m 3s) feel like I'm missing something I'm (200m 6s) missing something yeah because there's a (200m 9s) huge even at Google and so on YouTube uh (200m 10s) transcription yeah (200m 12s) um yeah it's unclear but some of it is (200m 14s) also integrating into a bigger system (200m 18s) yeah that so the user interface how it's (200m 19s) deployed and all that kind of stuff (200m 21s) maybe running it as an independent thing (200m 23s) is eat much easier like an order of (200m 25s) magnitude easier than deploying to a (200m 27s) large integrated system like YouTube (200m 30s) transcription or (200m 32s) um anything like meetings like Zoom has (200m 34s) trans transcription that's kind of (200m 37s) crappy but creating uh interface where (200m 38s) it detects the different individual (200m 42s) speakers it's able to (200m 42s) um (200m 46s) display it in compelling ways Run in (200m 46s) real time all that kind of stuff maybe (200m 50s) that's difficult but that's the only (200m 52s) explanation I have because like um (200m 55s) I'm currently paying uh quite a bit for (200m 57s) human uh transcription human caption (201m 0s) right annotation and like it seems like (201m 3s) uh there's a huge incentive to automate (201m 4s) that yeah it's very confusing and I (201m 5s) think I mean I don't know if you looked (201m 7s) at some of the whisper transcripts but (201m 9s) they're quite good they're good and (201m 11s) especially in tricky cases yeah I've (201m 13s) seen (201m 15s) uh Whispers performance on like super (201m 17s) tricky cases and it does incredibly well (201m 20s) so I don't know a podcast is pretty (201m 23s) simple it's like high quality audio and (201m 25s) you're speaking usually pretty clearly (201m 28s) and so I don't know it uh I don't know (201m 32s) what open ai's plans are yeah either but (201m 33s) yeah there's always like fun fun (201m 35s) projects basically and stable diffusion (201m 36s) also is opening up a huge amount of (201m 37s) experimentation I would say in the (201m 39s) visual realm and generate generating (201m 43s) images and videos and movies videos now (201m 44s) and so that's going to be pretty crazy (201m 46s) uh that's going to that's going to (201m 49s) almost certainly work and it's going to (201m 50s) be really interesting when the cost of (201m 52s) content creation is going to fall to (201m 54s) zero you used to need a painter for a (201m 55s) few months to paint a thing and now it's (201m 57s) going to be speak to your phone to get (202m 0s) your video so if Hollywood will start (202m 3s) using that to generate scene means (202m 6s) which completely opens up yeah so you (202m 8s) can make a like a movie like Avatar (202m 11s) eventually for und ...

# %%
full_text = " ".join([item['text'] for item in test])
full_text
# Out:
# "think it's possible that physics has exploits and we should be trying to find them arranging some kind of a crazy quantum mechanical system that somehow gives you buffer overflow somehow gives you a rounding error in the floating Point synthetic intelligences are kind of like the next stage of development and I don't know where it leads to like at some point I suspect the universe is some kind of a puzzle these synthetic AIS will uncover that puzzle and solve it the following is a conversation with Andre capothy previously the director of AI at Tesla and before that at open Ai and Stanford he is one of the greatest scientists engineers and Educators in the history of artificial intelligence this is the Lex Friedman podcast to support it please check out our sponsors and now dear friends here's Andre capathi what is a neural network and why does it seem to uh do such a surprisingly good job of learning what is a neural network it's a mathematical abstraction of the brain I would say that's how it was originally developed at the end of the day it's a mathematical expression and it's a fairly simple mathematical expression when you get down to it it's basically a sequence of Matrix multiplies which are really dot products mathematically and some nonlinearities thrown in and so it's a very simple mathematical expression and it's got knobs in it many knobs many knobs and these knobs are Loosely related to basically the synapses in your brain they're trainable they're modifiable and so the idea is like we need to find the setting of The Knobs that makes the neural nut do whatever you want it to do like classify images and so on and so there's not too much mystery I would say in it like um you might think that basically don't want to endow it with too much meaning with respect to the brain and how it works it's really just a complicated mathematical expression with knobs and those knobs need a proper setting for it to do something uh desirable yeah but poetry is just the collection of letters with spaces but it can make us feel a certain way and in that same way when you get a large number of knobs together whether it's in a inside the brain or inside a computer they seem to they seem to surprise us with the with their power yeah I think that's fair so basically I'm underselling it by a lot because you definitely do get very surprising emergent behaviors out of these neurons when they're large enough and trained on complicated enough problems like say for example the next uh word prediction in a massive data set from the internet and then these neurons take on a pretty surprising magical properties yeah I think it's kind of interesting how much you can get out of even very simple mathematical formalism when your brain right now I was talking is it doing next word prediction or is it doing something more interesting well definitely some kind of a generative model that's a gpt-like and prompted by you um yeah so you're giving me a prompt and I'm kind of like responding to it in a generative way and by yourself perhaps a little bit like are you adding extra prompts from your own memory inside your head automatically feels like you're referencing some kind of a declarative structure of like memory and so on and then uh you're putting that together with your prompt and giving away some messages like how much of what you just said has been said by you before uh nothing basically right no but if you actually look at all the words you've ever said in your life and you do a search you'll probably said a lot of the same words in the same order before yeah it could be I mean I'm using phrases that are common Etc but I'm remixing it into a pretty uh sort of unique sentence at the end of the day but you're right definitely there's like a ton of remixing what you didn't you it's like Magnus Carlsen said uh I'm I'm rated 2900 whatever which is pretty decent I think you're talking very uh you're not giving enough credit to neural Nets here why do t ...

# %%
with open("transcript.txt", "w") as file:
    file.write(full_text)

# %%
import pytube as pt
link = "https://www.youtube.com/watch?v=cdiD-9MMpb0"
# Create a YouTube object
yt = pt.YouTube(link)
# Print the title of the YouTube video
print("Title :", yt.title)
# Print the number of views of the YouTube video
print("Views :", yt.views)
# Print the description of the YouTube video
print("Description :", yt.description)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import pytubex as pt
#       2 link = "https://www.youtube.com/watch?v=cdiD-9MMpb0"
#       3 # Create a YouTube object
#
# ModuleNotFoundError: No module named 'pytubex'

# %%
# importing the libraries 
from bs4 import BeautifulSoup 
import requests 
  
# creating function 
def scrape_info(url): 
      
    # getting the request from url 
    r = requests.get(url) 
      
    # converting the text 
    s = BeautifulSoup(r.text, "html.parser") 
      
    # finding the button and clicking it
    button = s.find(id ='description')
    if button:
        button.click()
        # finding the description
        description = s.find('ytd-text-inline-expander', {'id': 'description-inline-expander'})
        if description:
            print(description.text.strip())

# %%
# URL of the video 
url ="https://www.youtube.com/watch?v=cdiD-9MMpb0"
      
# calling the function 
scrape_info(url)

# %%
import re
soup = BeautifulSoup(requests.get('https://www.youtube.com/watch?v=cdiD-9MMpb0').content)
pattern = re.compile('(?<=shortDescription":").*(?=","isCrawlable)')
description = pattern.findall(str(soup))[0].replace('\\n','\n')
print(description)
# Out:
# Andrej Karpathy is a legendary AI researcher, engineer, and educator. He's the former director of AI at Tesla, a founding member of OpenAI, and an educator at Stanford. Please support this podcast by checking out our sponsors:
# - Eight Sleep: https://www.eightsleep.com/lex to get special savings
# - BetterHelp: https://betterhelp.com/lex to get 10% off
# - Fundrise: https://fundrise.com/lex
# - Athletic Greens: https://athleticgreens.com/lex to get 1 month of fish oil
#
# EPISODE LINKS:
# Andrej's Twitter: http://twitter.com/karpathy
# Andrej's YouTube: http://youtube.com/c/AndrejKarpathy
# Andrej's Website: http://karpathy.ai
# Andrej's Google Scholar: http://scholar.google.com/citations?user=l8WuQJgAAAAJ
# Books mentioned:
# The Vital Question: https://amzn.to/3q0vN6q
# Life Ascending: https://amzn.to/3wKIsOE
# The Selfish Gene: https://amzn.to/3TCo63s
# Contact: https://amzn.to/3W3y5Au
# The Cell: https://amzn.to/3W5f6pa
#
# PODCAST INFO:
# Podcast website: https://lexfridman.com/podcast
# Apple Podcasts: https://apple.co/2lwqZIr
# Spotify: https://spoti.fi/2nEwCF8
# RSS: https://lexfridman.com/feed/podcast/
# Full episodes playlist: https://www.youtube.com/playlist?list=PLrAXtmErZgOdP_8GztsuKi9nrraNbKKp4
# Clips playlist: https://www.youtube.com/playlist?list=PLrAXtmErZgOeciFP3CBCIEElOJeitOr41
#
# OUTLINE:
# 0:00 - Introduction
# 0:58 - Neural networks
# 6:01 - Biology
# 11:32 - Aliens
# 21:43 - Universe
# 33:34 - Transformers
# 41:50 - Language models
# 52:01 - Bots
# 58:21 - Google's LaMDA
# 1:05:44 - Software 2.0
# 1:16:44 - Human annotation
# 1:18:41 - Camera vision
# 1:23:46 - Tesla's Data Engine
# 1:27:56 - Tesla Vision
# 1:34:26 - Elon Musk
# 1:39:33 - Autonomous driving
# 1:44:28 - Leaving Tesla
# 1:49:55 - Tesla's Optimus
# 1:59:01 - ImageNet
# 2:01:40 - Data
# 2:11:31 - Day in the life
# 2:24:47 - Best IDE
# 2:31:53 - arXiv
# 2:36:23 - Advice for beginners
# 2:45:40 - Artificial general intelligence
# 2:59:00 - Movies
# 3:04:53 - Future of human civilization
# 3:09:13 - Book recommendations
# 3:15:21 - Advice for young people
# 3:17:12 - Future of machine learning
# 3:24:00 - Meaning of life
#
# SOCIAL:
# - Twitter: https://twitter.com/lexfridman
# - LinkedIn: https://www.linkedin.com/in/lexfridman
# - Facebook: https://www.facebook.com/lexfridman
# - Instagram: https://www.instagram.com/lexfridman
# - Medium: https://medium.com/@lexfridman
# - Reddit: https://reddit.com/r/lexfridman
# - Support on Patreon: https://www.patreon.com/lexfridman

# %% [markdown]
# GPT API CAll to get outline:

# %% [markdown]
# Only Timestamps and Topic. Use JSON Mode.
# [
#     {"timestamp": "0:00", "topic": "Introduction"},
#     {"timestamp": "0:58", "topic": "Neural networks"},
#     {"timestamp": "6:01", "topic": "Biology"},
#     {"timestamp": "11:32", "topic": "Aliens"},
#     {"timestamp": "21:43", "topic": "Universe"},
#     {"timestamp": "33:34", "topic": "Transformers"},
#     {"timestamp": "41:50", "topic": "Language models"},
#     {"timestamp": "52:01", "topic": "Bots"},
#     {"timestamp": "58:21", "topic": "Google's LaMDA"},
#     {"timestamp": "1:05:44", "topic": "Software 2.0"},
#     {"timestamp": "1:16:44", "topic": "Human annotation"},
#     {"timestamp": "1:18:41", "topic": "Camera vision"},
#     {"timestamp": "1:23:46", "topic": "Tesla's Data Engine"},
#     {"timestamp": "1:27:56", "topic": "Tesla Vision"},
#     {"timestamp": "1:34:26", "topic": "Elon Musk"},
#     {"timestamp": "1:39:33", "topic": "Autonomous driving"},
#     {"timestamp": "1:44:28", "topic": "Leaving Tesla"},
#     {"timestamp": "1:49:55", "topic": "Tesla's Optimus"},
#     {"timestamp": "1:59:01", "topic": "ImageNet"},
#     {"timestamp": "2:01:40", "topic": "Data"},
#     {"timestamp": "2:11:31", "topic": "Day in the life"},
#     {"timestamp": "2:24:47", "topic": "Best IDE"},
#     {"timestamp": "2:31:53", "topic": "arXiv"},
#     {"timestamp": "2:36:23", "topic": "Advice for beginners"},
#     {"timestamp": "2:45:40", "topic": "Artificial general intelligence"},
#     {"timestamp": "2:59:00", "topic": "Movies"},
#     {"timestamp": "3:04:53", "topic": "Future of human civilization"},
#     {"timestamp": "3:09:13", "topic": "Book recommendations"},
#     {"timestamp": "3:15:21", "topic": "Advice for young people"},
#     {"timestamp": "3:17:12", "topic": "Future of machine learning"},
#     {"timestamp": "3:24:00", "topic": "Meaning of life"}
# ]

# %%
description = [
    {"timestamp": "00:00", "topic": "Intro"},
    {"timestamp": "06:06", "topic": "Success Through Action & Purpose"},
    {"timestamp": "14:01", "topic": "Cultivate Negative Capability"},
    {"timestamp": "18:17", "topic": "Remake Yourself"},
    {"timestamp": "28:35", "topic": "Judge People on Behaviour"},
    {"timestamp": "34:40", "topic": "Use Absence to Increase Respect"},
    {"timestamp": "39:45", "topic": "Become an Object of Desire"},
    {"timestamp": "43:47", "topic": "Time Lost Can Never Be Regained"},
    {"timestamp": "48:07", "topic": "The Madness of Groups"},
    {"timestamp": "52:46", "topic": "Suffer Fools Gladly"},
    {"timestamp": "58:11", "topic": "Accept Your Insignificance"},
    {"timestamp": "1:04:17", "topic": "Where to Find Robert"}
]

# %%
import json

with open('outline.json', 'r') as file:
    outline = json.load(file)

print(outline)

for item in outline:
    item["timestamp"] = timedelta(minutes=item["minutes"], seconds=item["seconds"])
# Out:
# [{'timestamp': '00:00', 'topic': 'Intro', 'minutes': 0, 'seconds': 0}, {'timestamp': '06:06', 'topic': 'Success Through Action & Purpose', 'minutes': 6, 'seconds': 6}, {'timestamp': '14:01', 'topic': 'Cultivate Negative Capability', 'minutes': 14, 'seconds': 1}, {'timestamp': '18:17', 'topic': 'Remake Yourself', 'minutes': 18, 'seconds': 17}, {'timestamp': '28:35', 'topic': 'Judge People on Behaviour', 'minutes': 28, 'seconds': 35}, {'timestamp': '34:40', 'topic': 'Use Absence to Increase Respect', 'minutes': 34, 'seconds': 40}, {'timestamp': '39:45', 'topic': 'Become an Object of Desire', 'minutes': 39, 'seconds': 45}, {'timestamp': '43:47', 'topic': 'Time Lost Can Never Be Regained', 'minutes': 43, 'seconds': 47}, {'timestamp': '48:07', 'topic': 'The Madness of Groups', 'minutes': 48, 'seconds': 7}, {'timestamp': '52:46', 'topic': 'Suffer Fools Gladly', 'minutes': 52, 'seconds': 46}, {'timestamp': '58:11', 'topic': 'Accept Your Insignificance', 'minutes': 58, 'seconds': 11}, {'timestamp': '1:04:17', 'topic': 'Where to Find Robert', 'minutes': 64, 'seconds': 17}]

# %%
time1 = outline[0]["timestamp"]
time2 = data[0]["timestamp"]

print(time1)
print(time2)
# Out:
# 0:00:00
# 0:00:03.060000
